# %%
import pandas as pd
import numpy as np
from multiprocessing import Pool
import matplotlib.pyplot as plt

# %%
pip install pymorphy2
# Out:
# Requirement already satisfied: pymorphy2 in d:\anaconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: docopt>=0.6 in d:\anaconda3\lib\site-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in d:\anaconda3\lib\site-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: dawg-python>=0.7.1 in d:\anaconda3\lib\site-packages (from pymorphy2) (0.7.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
habs = pd.read_csv("habs.csv")
posts = pd.read_csv("posts.csv")
tags = pd.read_csv("tags.csv")
posts.drop("Unnamed: 0", axis=1, inplace=True)
posts.dropna(subset=["text"], inplace=True)
df = posts.merge(habs, on="post_id").drop("Unnamed: 0", axis=1)
df = df.merge(tags, on="post_id").drop("Unnamed: 0", axis=1)

# %%
df.drop_duplicates(subset=["title", "views_count", "author_nickname"], inplace=True)

# %%
df.drop("post_id", axis=1, inplace=True)
df["date"] = pd.to_datetime(df["date"]).apply(lambda date : date.year)

# %%
df["title"] = df["title"] + " " + df["hab"] + " " + df["tag"]

# %%
df["start_post"] = df["text"].apply(lambda x : x[:40])

# %%
df["text_len"] = df["text"].apply(lambda x : len(x.split()))
    
quantiles = np.quantile(df["text_len"], [0.05, 0.99])
df = df[(df["text_len"] >= quantiles[0])&(df["text_len"] <= quantiles[1])]

# %%
import re

from pymorphy2 import MorphAnalyzer
from nltk.corpus import stopwords

patterns = "[a-zA-Z\d!#$%&'()*+,./:;<=>?@\[\]^_`{|}~—\"\-\n]+"
stopwords_ru = stopwords.words("russian")
morph = MorphAnalyzer()

def lemmatize(doc):
    doc = re.sub(patterns, ' ', doc)
    tokens = []
    for token in doc.split():
        if token and token not in stopwords_ru:
            token = token.strip()
            token = morph.normal_forms(token)[0]
            
            tokens.append(token)
            
    if len(tokens) > 2:
        return ' '.join(tokens)
    return None

# %%
df[df["text_len"] < 5000].to_csv("test.csv", columns=df.columns)

# %%
df.shape[0]
# Out:
# 216604

# %%
df.sample(3)
# Out:
#                                                      title  \
# 640305   Генерация документов. Легко и свободно Чулан г...
# 50446    Теория и практика использования HBase Блог ком...
# 1738779  Вышла вторая бета elementary OS Luna Настройка...
#
#                                                       text  date  views_count  \
# 640305   Продолжая тему генерации документов на основе ...  2017         3200
# 50446    Добрый день! Меня зовут Данил Липовой, наша ко...  2018         7600
# 1738779   \n\nelementary OS дистрибутив основанный на U...  2013        31400
#
#          comments_count  bookmarks_count rating author_nickname  \
# 640305               22                2     –9       PennyLane
# 50446                11               47    +12    pustota_2009
# 1738779              19               71    +20            fork
#
#                             hab        tag  \
# 640305                    Чулан  генератор
# 50446    Блог компании Сбербанк      hbase
# 1738779         Настройка Linux      linux
#
#                                          start_post  text_len
# 640305     Продолжая тему генерации документов на о       258
# 50446      Добрый день! Меня зовут Данил Липовой, н      3180
# 1738779   \n\nelementary OS дистрибутив основанный        286

# %%
df.drop(columns=["date", "comments_count", "views_count", "author_nickname", "hab", "tag", "start_post"], inplace=True)

# %%
def change_rating(rate):
    if rate:
        if rate[0] == "+":
            return int(rate[1:])
        elif rate[0] == "–":
            return -int(rate[1:])
        else:
            return int(rate)
        
df["rating"] = df["rating"].apply(change_rating)

# %%
df["rating"] = df["rating"] + 2 * df["bookmarks_count"]
df.drop("bookmarks_count", axis=1, inplace=True)

# %%
df.drop("text_len", axis=1, inplace=True)

# %%
df.to_csv("dataset.csv", index=False)

# %%
df = pd.read_csv("documents.csv")
df.sample(3)
# Out:
#                                                     title  \
# 170379  На чем писать десктопного клиента для веб-серв...
# 15655   IT, откуда не ждали Блог компании Dell Technol...
# 95930   Изменения в правилах Интернет-магазина Chrome:...
#
#                                                      text  rating
# 170379  такой вопрос задаться возникнуть необходимость...     120
# 15655   как понимать шутка появляться просто появлятьс...     111
# 95930   в правило интернет магазин произойти изменение...      26

# %%
df["text"].isna().sum()
# Out:
# 0

# %%
df = df.dropna(subset=["text"])

# %%
lenghts = df["text"].apply(lambda x : len(x.split()))

# %%
def isfloat(number):
    if type(number) is float:
        return True
    else:
        return False

df.drop(index=df[df["title"].apply(lambda x : isfloat(x))].index, inplace=True)

# %%
df["text"] = df["text"] + " " + df["title"]

# %%
df = df[lenghts > 49]

# %%
df.to_csv("documents.csv", index=False)

# %%
df = pd.read_csv("documents.csv")

# %%
data = [text.split() for text in df["text"].values[:10]]
data
# Out:
# [['разработчик',
#   'объявить',
#   'появиться',
#   'возможность',
#   'добавлять',
#   'профиль',
#   'сертификат',
#   'диплом',
#   'онлайн',
#   'курс',
#   'университет',
#   'нажатие',
#   'один',
#   'кнопка',
#   'это',
#   'расширение',
#   'анонсировать',
#   'рамка',
#   'продолжение',
#   'политика',
#   'непрерывность',
#   'профессиональный',
#   'образовательный',
#   'пространство',
#   'встроить',
#   'новый',
#   'информация',
#   'профиль',
#   'нажать',
#   'один',
#   'кнопка',
#   'помощь',
#   'онлайн',
#   'виджет',
#   'уже',
#   'университет',
#   'установить',
#   'свой',
#   'сайт',
#   'функция',
#   'мгновенный',
#   'добавление',
#   'степень',
#   'портфолио',
#   'среди',
#   'университет',
#   'джордж',
#   'вашингтон',
#   'калифорнийский',
#   'университет',
#   'университет',
#   'штат',
#   'аризона',
#   'университет',
#   'кейо',
#   'кембридж',
#   'мельбурн',
#   'проч',
#   'также',
#   'партнёр',
#   'выступить',
#   'такой',
#   'моос',
#   'платформа',
#   'другой',
#   'курс',
#   '«в',
#   'пользователь',
#   'получать',
#   'сертификат',
#   'например',
#   'сертификат',
#   'специалист',
#   'область',
#   'медицинский',
#   'оборудование',
#   'сертификат',
#   'обучение',
#   'специальность',
#   'мерчендайзер',
#   'супервайзер',
#   'чем',
#   'далёкий',
#   'такой',
#   'сертификат',
#   'и',
#   'наш',
#   'план',
#   'входить',
#   'прикрутка',
#   '»',
#   'сообщать',
#   'сооснователь',
#   'владимир',
#   'щербаков',
#   'онлайн',
#   'научиться',
#   'что',
#   'угодный',
#   'LinkedIn',
#   'автоматизировал',
#   'добавление',
#   'в',
#   'профиль',
#   'сертификатов',
#   'и',
#   'дипломов',
#   'от',
#   'онлайн-курсов',
#   'Блог',
#   'компании',
#   'Teachbase.ru',
#   'LinkedIn',
#   'LinkedIn',
#   'автоматизировал',
#   'добавление',
#   'в',
#   'профиль',
#   'сертификатов',
#   'и',
#   'дипломов',
#   'от',
#   'онлайн-курсов',
#   'Блог',
#   'компании',
#   'Teachbase.ru',
#   'LinkedIn'],
#  ['с',
#   'свой',
#   'мобильник',
#   'заказывать',
#   'фальшивый',
#   'звонок',
#   'устанавливать',
#   'таймер',
#   'указывать',
#   'точный',
#   'время',
#   'после',
#   'ждать',
#   'мобильник',
#   'зазвонить',
#   'голос',
#   'трубка',
#   'продиктовать',
#   'точный',
#   'фраза',
#   'интонация',
#   'вы',
#   'просто',
#   'повторять',
#   'каждый',
#   'слово',
#   '«алло',
#   'да…',
#   'неужели',
#   'не',
#   'а',
#   'остаться',
#   'ключ',
#   'хорошо',
#   'еда',
#   '»',
#   'мочь',
#   'смело',
#   'срываться',
#   'любой',
#   'свидание',
#   'деловой',
#   'встреча',
#   'который',
#   'надоесть',
#   'всё',
#   'окружающий',
#   'отлично',
#   'слышать',
#   'разговор',
#   'понять',
#   'нужно',
#   'убегать',
#   'что',
#   'представлять',
#   'фальшивый',
#   'звонок',
#   'якобы',
#   'парень',
#   'видно',
#   'слышный',
#   'видео',
#   'вот',
#   'случай',
#   'фальшивый',
#   'звонок',
#   'сосед',
#   'насчёт',
#   'забытый',
#   'ключ',
#   'видео',
#   'в',
#   'оба',
#   'случай',
#   'мобильник',
#   'использоваться',
#   'социальный',
#   'оружие',
#   'особенно',
#   'популярный',
#   'подобный',
#   'сервис',
#   'америка',
#   'лицемерие',
#   'считаться',
#   'норма',
#   'поведение',
#   'проявить',
#   'недружелюбность',
#   'сказать',
#   'нечто',
#   'обидный',
#   'собеседник',
#   'такой',
#   'поведение',
#   'весь',
#   'осуждаться',
#   'человек',
#   'мочь',
#   'отправить',
#   'врач',
#   'прописать',
#   'антидепрессант',
#   'что',
#   'оставаться',
#   'только',
#   'лицемерие',
#   'технологический',
#   'помощник',
#   'такой',
#   'сервис',
#   'впервые',
#   'подобный',
#   'сервис',
#   '«фальшивый',
#   'звонков»',
#   'появиться',
#   'лето',
#   'г',
#   'позиционироваться',
#   'молодой',
#   'человек',
#   'который',
#   'хотеть',
#   'быстро',
#   'сбежать',
#   'свидание',
#   'теперь',
#   'такой',
#   'услуга',
#   'иметься',
#   'оператор',
#   'мобильный',
#   'связь',
#   'список',
#   'ситуация',
#   'фальшивый',
#   'звонок',
#   'значительно',
#   'расшириться',
#   'появиться',
#   'дополнительный',
#   'услуга',
#   'фальшивый',
#   'звонок',
#   'заказать',
#   'любой',
#   'телефон',
#   'обычный',
#   '«смской»',
#   'однако',
#   'весь',
#   'набор',
#   'услуга',
#   'доступный',
#   'помощь',
#   'специальный',
#   'программа',
#   'который',
#   'устанавливаться',
#   'телефон',
#   'флэш',
#   'демонстрация',
#   'как',
#   'видеть',
#   'кроме',
#   'фальшивый',
#   'звонок',
#   'фальшивый',
#   'телефонный',
#   'номер',
#   'такой',
#   'номер',
#   'дать',
#   'незадачливый',
#   'ухажёр',
#   'если',
#   'неудачник',
#   'туда',
#   'позвонить',
#   'послать',
#   'далёкий',
#   'в',
#   'список',
#   'дополнительный',
#   'услуга',
#   'последний',
#   'новость',
#   'мода',
#   'сплетня',
#   'кинозвезда',
#   'идея',
#   'разговор',
#   'знакомство',
#   'хороший',
#   'фраза',
#   'отказ',
#   'тест',
#   'алкоголь',
#   'выпить',
#   'владелец',
#   'мобильник',
#   'показывать',
#   'фотография',
#   'девушка',
#   'находить',
#   'привлекательный',
#   'точно',
#   'садиться',
#   'руль',
#   'это',
#   'крайний',
#   'степень',
#   'опьянение',
#   'MobileFaker:',
#   'фальшивые',
#   'звонки',
#   'как',
#   'социальное',
#   'оружие',
#   'Чулан',
#   'MobileFaker',
#   'MobileFaker:',
#   'фальшивые',
#   'звонки',
#   'как',
#   'социальное',
#   'оружие',
#   'Чулан',
#   'MobileFaker'],
#  ['облачный',
#   'хостинг',
#   'ранее',
#   'разработать',
#   'новый',
#   'приложение',
#   'отличительный',
#   'особенность',
#   'поддержка',
#   'стандартный',
#   'стек',
#   'технология',
#   'привязка',
#   'проприетарный',
#   'платформа',
#   'визуальный',
#   'конструктор',
#   'топология',
#   'визуализация',
#   'создание',
#   'топология',
#   'окружение',
#   'вертикальный',
#   'масштабирование',
#   'наличие',
#   'который',
#   'являться',
#   'критически',
#   'важный',
#   'определённый',
#   'вид',
#   'приложение',
#   'широкий',
#   'набор',
#   'база',
#   'данные',
#   'сервер',
#   'приложение',
#   'близкий',
#   'будущее',
#   'набор',
#   'расширить',
#   'мы',
#   'продолжать',
#   'развитие',
#   'рада',
#   'сообщить',
#   'увеличение',
#   'посадочный',
#   'место',
#   'борт',
#   'всё',
#   'ранее',
#   'получить',
#   'доступ',
#   'мочь',
#   'входить',
#   'дополнительный',
#   'регистрация',
#   'остальной',
#   'желать',
#   'просить',
#   'оставить',
#   'заявка',
#   'отдельный',
#   'большой',
#   'спасибо',
#   'весь',
#   'вложить',
#   'персональный',
#   'вклад',
#   'развитие',
#   'наш',
#   'продукт',
#   'некоторый',
#   'пользователь',
#   'проявить',
#   'очень',
#   'высокий',
#   'интерес',
#   'либо',
#   'наслать',
#   'баг',
#   'либо',
#   'сделать',
#   'очень',
#   'важный',
#   'предложение',
#   'развитие',
#   'отдельный',
#   'благодарность',
#   'наш',
#   'пользователь',
#   'который',
#   'сожаление',
#   'хабра',
#   'он',
#   'создать',
#   'плагин',
#   'плагин',
#   'собственный',
#   'инициатива',
#   'в',
#   'текущий',
#   'релиз',
#   'визуальный',
#   'конструктор',
#   'топология',
#   'возможность',
#   'включение',
#   'топология',
#   'приложение',
#   'базис',
#   'горизонтальный',
#   'масштабирование',
#   'балансировка',
#   'нагрузка',
#   'два',
#   'инстанс',
#   'поддержка',
#   'проксирование',
#   'статический',
#   'файл',
#   'быстрый',
#   'отдача',
#   'клиент',
#   'добавить',
#   'поддержка',
#   'новый',
#   'программный',
#   'стек',
#   'уменьшить',
#   'шаг',
#   'масштабирование',
#   'память',
#   'мб',
#   'поддержка',
#   'разный',
#   'контекст',
#   'деплоить',
#   'приложение',
#   'загрузка',
#   'пользовательский',
#   'библиотека',
#   'ядро',
#   'сервер',
#   'расширить',
#   'возможность',
#   'редактирование',
#   'файл',
#   'конфигурация',
#   'загрузка',
#   'файл',
#   'конфигурация',
#   'локальный',
#   'диск',
#   'окружение',
#   'умолчание',
#   'получать',
#   'домен',
#   'возможность',
#   'биндинга',
#   'внешний',
#   'домен',
#   'второй',
#   'уровень',
#   'доступ',
#   'инстанс',
#   'алиас',
#   'пример',
#   'улучшить',
#   'менеджер',
#   'статистика',
#   'доработать',
#   'менеджер',
#   'лог',
#   'улучшить',
#   'графический',
#   'интерфейс',
#   'исправить',
#   'серьёзный',
#   'мелкий',
#   'баг',
#   'документация',
#   'видео',
#   'пример',
#   'уже',
#   'подход',
#   'такой',
#   'функция',
#   '«горячее»',
#   'переключение',
#   'окружение',
#   'клонирование',
#   'окружение',
#   'целиком',
#   'прочий',
#   'менее',
#   'необходимый',
#   'функция',
#   'ждать',
#   'ваш',
#   'предложение',
#   'замечание',
#   'оставаться',
#   'мы',
#   'волна',
#   'мы',
#   'Jelastic',
#   'is',
#   'the',
#   'new',
#   'kind',
#   'of',
#   'Java',
#   'hosting',
#   'platform',
#   'Блог',
#   'компании',
#   'Jelastic',
#   'java',
#   'Jelastic',
#   'is',
#   'the',
#   'new',
#   'kind',
#   'of',
#   'Java',
#   'hosting',
#   'platform',
#   'Блог',
#   'компании',
#   'Jelastic',
#   'java'],
#  ['относительно',
#   'новый',
#   'операционный',
#   'система',
#   'который',
#   'позиционироваться',
#   'разработчик',
#   'программный',
#   'платформа',
#   'смартфон',
#   'планшет',
#   'недавно',
#   'этот',
#   'ос',
#   'появиться',
#   'умный',
#   'тв',
#   'также',
#   'аксессуар',
#   'телевизор',
#   'спустя',
#   'некоторый',
#   'время',
#   'специальный',
#   'версия',
#   'появиться',
#   'носить',
#   'устройство',
#   'сейчас',
#   'вестись',
#   'активный',
#   'работа',
#   'адаптация',
#   'умный',
#   'часы',
#   'очки',
#   'другой',
#   'устройство',
#   'конечно',
#   'несколько',
#   'отставать',
#   'чей',
#   'начало',
#   'путешествовать',
#   'мир',
#   'тем',
#   'менее',
#   'ниша',
#   'носить',
#   'устройство',
#   'найти',
#   'очень',
#   'широкий',
#   'спектр',
#   'выпускать',
#   'различный',
#   'производитель',
#   'девайс',
#   'и',
#   'весь',
#   'хотеться',
#   'платить',
#   'производитель',
#   'готовый',
#   'программный',
#   'решение',
#   'некоторый',
#   'компания',
#   'искать',
#   'дешёвый',
#   'альтернатива',
#   'решение',
#   'являться',
#   'полностью',
#   'открытый',
#   'сторонний',
#   'разработчик',
#   'смочь',
#   'адаптировать',
#   'различный',
#   'устройство',
#   'в',
#   'время',
#   'решение',
#   'также',
#   'являться',
#   'открытый',
#   'разработчик',
#   '«корпорация',
#   'добра»',
#   'выкладывать',
#   'исходный',
#   'код',
#   'свой',
#   'решение',
#   'выпустить',
#   'коммерческий',
#   'версия',
#   'тот',
#   'либо',
#   'иной',
#   'версия',
#   'программный',
#   'продукт',
#   'реальный',
#   'разработка',
#   'вестись',
#   'выразиться',
#   'закрытый',
#   'дверь',
#   'пока',
#   'дата',
#   'выход',
#   'носить',
#   'устройство',
#   'неизвестный',
#   'В',
#   'Mozilla',
#   'работают',
#   'над',
#   'версией',
#   'Firefox',
#   'OS',
#   'для',
#   'носимых',
#   'устройств',
#   'Гаджеты',
#   'Firefox',
#   'OS',
#   'В',
#   'Mozilla',
#   'работают',
#   'над',
#   'версией',
#   'Firefox',
#   'OS',
#   'для',
#   'носимых',
#   'устройств',
#   'Гаджеты',
#   'Firefox',
#   'OS'],
#  ['введение',
#   'в',
#   'небольшой',
#   'статья',
#   'хотеть',
#   'рассказать',
#   'настраивать',
#   'отправка',
#   'почта',
#   'это',
#   'закончиться',
#   'хотеть',
#   'сразу',
#   'уточнить',
#   'два',
#   'вещь',
#   'первый',
#   'делать',
#   'это',
#   'рассылка',
#   'спам',
#   'второй',
#   'ранее',
#   'иметь',
#   'дело',
#   'настройка',
#   'почтовый',
#   'сервер',
#   'поскольку',
#   'это',
#   'лежать',
#   'вне',
#   'область',
#   'мой',
#   'профессиональный',
#   'деятельность',
#   'настройка',
#   'решать',
#   'один',
#   'свой',
#   'задача',
#   'столкнуться',
#   'необходимость',
#   'рассылать',
#   'пользователь',
#   'дать',
#   'аутентификация',
#   'так',
#   'быть',
#   'логин',
#   'пароль',
#   'который',
#   'лежать',
#   'таблица',
#   'скажем',
#   'откровенно',
#   'данный',
#   'момент',
#   'пользователь',
#   'сотня',
#   'тысяча',
#   'каждый',
#   'отослать',
#   'письмо',
#   'рука',
#   'это',
#   'пара',
#   'час',
#   'ручной',
#   'труд',
#   '–',
#   'интересный',
#   'потратить',
#   'раз',
#   'время',
#   'автоматизировать',
#   'на',
#   'прошлый',
#   'место',
#   'работа',
#   'приходиться',
#   'слать',
#   'джоб',
#   'ежемесячный',
#   'отчёт',
#   'почта',
#   'пользователь',
#   'задача',
#   'выглядеть',
#   'экзотичный',
#   'рассчитывать',
#   'справиться',
#   'соизмеримый',
#   'ручной',
#   'труд',
#   'время',
#   'с',
#   'сторона',
#   'весь',
#   'необходимый',
#   'инфраструктура',
#   'рука',
#   'специалист',
#   'нужный',
#   'тематика',
#   'который',
#   'поговорить',
#   'здесь',
#   'нужно',
#   'разбираться',
#   'сам',
#   'иметь',
#   'множество',
#   'метод',
#   'отсылка',
#   'почта',
#   'бд',
#   'некоторый',
#   'пакет',
#   'иметь',
#   'нужный',
#   'функциональность',
#   'любой',
#   'перечисленный',
#   'пакет',
#   'полностью',
#   'содержать',
#   'необходимый',
#   'логика',
#   'самый',
#   'свежий',
#   '–',
#   'это',
#   'пакет',
#   'решить',
#   'использовать',
#   'сказать',
#   'сразу',
#   'пакет',
#   'входить',
#   'сборка',
#   'умолчание',
#   'нужно',
#   'устанавливать',
#   'рука',
#   'часть',
#   'пакет',
#   'лежать',
#   'два',
#   'файл',
#   'спецификация',
#   'пакет',
#   'находиться',
#   'файл',
#   '\\',
#   '\\',
#   '\\',
#   'тело',
#   'пакет',
#   'зашифровать',
#   'лежать',
#   'файл',
#   '\\',
#   '\\',
#   '\\',
#   'накатывать',
#   'это',
#   'нужно',
#   'пользователь',
#   'нормально',
#   'установить',
#   'пакет',
#   '’',
#   'удаться',
#   'так',
#   'быть',
#   'установиться',
#   'выдавать',
#   'ошибка',
#   'компиляция',
#   'из',
#   'установиться',
#   'отлично',
#   'после',
#   'накат',
#   'нужно',
#   'выдать',
#   'грант',
#   'использование',
#   'пакет',
#   'некоторый',
#   'автор',
#   'предлагать',
#   'давать',
#   'грант',
#   'это',
#   'хороший',
#   'идея',
#   'причина',
#   'безопасность',
#   'после',
#   'выдача',
#   'грант',
#   'нужный',
#   'пользователь',
#   'наш',
#   'работа',
#   'пользователь',
#   'закончить',
#   'однако',
#   'мы',
#   'понадобиться',
#   'ситуация',
#   'нужно',
#   'делать',
#   'почтовый',
#   'сервер',
#   'как',
#   'оказаться',
#   'отправка',
#   'почта',
#   'нужный',
#   'инфраструктура',
#   'так',
#   'быть',
#   'кроме',
#   'нужный',
#   'почтовый',
#   'сервер',
#   'который',
#   'устанавливать',
#   'настраивать',
#   'вообще',
#   'представлять',
#   'нужно',
#   'после',
#   'недолгий',
#   'поиск',
#   'найти',
#   'следующий',
#   'статья',
#   'описывать',
#   'слать',
#   'почта',
#   'автор',
#   'статья',
#   'попасть',
#   'аналогичный',
#   'мой',
#   'ситуация',
#   'предлагать',
#   'простой',
#   'решение',
#   'который',
#   'решить',
#   'воспользоваться',
#   'завести',
#   'новый',
#   'ящик',
#   'который',
#   'использоваться',
#   'автоматический',
#   'отсылка',
#   'письмо',
#   'скачать',
#   'установить',
#   'сразу',
#   'заработать',
#   'прийтись',
#   'немного',
#   'почитать',
#   'документация',
#   'поискать',
#   'стать',
#   'описывать',
#   'взаимодействие',
#   'данные',
#   'сервер',
#   'в',
#   'итог',
#   'нужный',
#   'параметр',
#   'внести',
#   'файл',
#   'дать',
#   'почтовый',
#   'ящик',
#   'файл',
#   'сервер',
#   'успешно',
#   'запустить',
#   'отправка',
#   'письмо',
#   'после',
#   'установка',
#   'почтовый',
#   'сервер',
#   'проксить',
#   'наш',
#   'случай',
#   'нужно',
#   'указать',
#   'адрес',
#   'в',
#   'мой',
#   'случай',
#   'проксить',
#   'стоять',
#   'один',
#   'машина',
#   'поэтому',
#   'адрес',
#   'порт',
#   'попытаться',
#   'отправить',
#   'письмо',
#   'помощь',
#   'прийтись',
#   'немного',
#   'поиграться',
#   'настройка',
#   'например',
#   'оказаться',
#   'поле',
#   'обязательно',
#   'нужный',
#   'адрес',
#   'следующий',
#   'формат',
#   'указать',
#   'имя',
#   'отправитель',
#   'письмо',
#   'прийти',
#   'равно',
#   'ваш',
#   'реальный',
#   'ящик',
#   'выглядеть',
#   'это',
#   'немного',
#   'эксперимент',
#   'отсылка',
#   'разный',
#   'почтовый',
#   'сервер',
#   'показать',
#   'русский',
#   'текст',
#   'желательно',
#   'использовать',
#   '«',
#   '»',
#   'после',
#   'контрольный',
#   'отсылка',
#   'письмо',
#   'написать',
#   'процедура',
#   'который',
#   'выбирать',
#   'нужный',
#   'дать',
#   'слать',
#   'каждый',
#   'пользователь',
#   'логин',
#   'пароль',
#   'запустить',
#   'процедура',
#   'отсылка',
#   'данные',
#   'первый',
#   'двадцать',
#   'пользователь',
#   'уйти',
#   'обедать',
#   'минута',
#   'оказаться',
#   'уйти',
#   'первый',
#   'письмо',
#   'остальной',
#   'застрять',
#   'готовиться',
#   'дебаг',
#   'отправить',
#   'тот',
#   'процедура',
#   'письмо',
#   'ящик',
#   'новый',
#   'пакет',
#   '«протолкнул»',
#   'потерянный',
#   'письмо',
#   'успешно',
#   'уйти',
#   'в',
#   'общий',
#   'проксить',
#   'работать',
#   'хотя',
#   'некоторый',
#   'непостоянство',
#   'продолжение',
#   'история',
#   'через',
#   'день',
#   'заниматься',
#   'свой',
#   'дело',
#   'сервер',
#   'увидеть',
#   'проксить',
#   'отослать',
#   'около',
#   'письмо',
#   'хотя',
#   'первый',
#   'рассылка',
#   'отправлять',
#   'решить',
#   'проверить',
#   'ящик',
#   '’',
#   'в',
#   'входящий',
#   'красоваться',
#   'пачка',
#   'письмо',
#   'всё',
#   'цепочка',
#   'содержать',
#   'ответ',
#   'почтовый',
#   'сервер',
#   'отправка',
#   'сообщение',
#   'несуществующий',
#   'ящик',
#   'в',
#   'отправить',
#   'сообщение',
#   'наблюдаться',
#   'следующий',
#   'картина',
#   'получаться',
#   'мой',
#   'ящик',
#   'уйти',
#   'письмо',
#   'ящик',
#   'причём',
#   'каждый',
#   'письмо',
#   'тема',
#   'содержать',
#   'адрес',
#   'машина',
#   'который',
#   'стоять',
#   'проксить',
#   'тело',
#   'письмо',
#   'пустой',
#   'письмо',
#   'иметь',
#   'один',
#   'аттач',
#   'имя',
#   'размер',
#   'ноль',
#   'байт',
#   'очевидный',
#   'проксить',
#   'иметь',
#   'уязвимость',
#   'неизвестно',
#   'проявляться',
#   'отправка',
#   'письмо',
#   'аттакать',
#   'аттач',
#   'должный',
#   'содержать',
#   'какой',
#   'дополнительный',
#   'информация',
#   'относительно',
#   'уязвимость',
#   'характеристика',
#   'машина',
#   'поскольку',
#   'время',
#   'отправка',
#   'сообщение',
#   'оба',
#   'ящик',
#   'совпадать',
#   'делать',
#   'вывод',
#   'принадлежать',
#   'один',
#   'тот',
#   'человек',
#   'в',
#   'результат',
#   'найти',
#   'уязвимость',
#   'проксить',
#   'послать',
#   'письмо',
#   'такой',
#   'вид',
#   'гугл',
#   'транслейт',
#   'определять',
#   'язык',
#   'письмо',
#   'китайский',
#   'поиск',
#   'гугл',
#   'информация',
#   'данные',
#   'быть',
#   'мейл',
#   'показать',
#   'пользователь',
#   'часто',
#   'жаловаться',
#   'непонятный',
#   'активность',
#   'почтовый',
#   'сервер',
#   'связанный',
#   'отсылка',
#   'письмо',
#   'ящик',
#   'в',
#   'общий',
#   'словарь',
#   'появиться',
#   'словосочетание',
#   '«',
#   '»',
#   'проксить',
#   'выключить',
#   'остаться',
#   'вопрос',
#   'это',
#   'делать',
#   'далёкий',
#   'я',
#   'видеть',
#   'вариант',
#   'поскольку',
#   'почта',
#   'отправлять',
#   'планироваться',
#   'часто',
#   'целый',
#   'пакет',
#   'оставить',
#   'так',
#   'быть',
#   'включать',
#   'почтовый',
#   'проксить',
#   'время',
#   'отправка',
#   'письмо',
#   '–',
#   'наиболее',
#   'дешёвый',
#   'время',
#   'решение',
#   'можно',
#   'досконально',
#   'разобраться',
#   'тема',
#   'почтовый',
#   'сервер',
#   'либо',
#   'корректно',
#   'настроить',
#   'данный',
#   'либо',
#   'сменить',
#   'надёжный',
#   '–',
#   'довольно',
#   'дорога',
#   'время',
#   'вариант',
#   'тот',
#   'дальнейший',
#   'знание',
#   'быть',
#   'абсолютно',
#   'бесполезный',
#   'найти',
#   'воркэраунд',
#   'использование',
#   'иметься',
#   'знание',
#   '–',
#   'затрата',
#   'время',
#   'известный',
#   'найти',
#   'разбираться',
#   'почтовый',
#   'сервер',
#   'знакомый',
#   'учитывать',
#   'исходный',
#   'задача',
#   'наиболее',
#   'перспективный',
#   'выглядеть',
#   'ия',
#   'вариант',
#   'условие',
#   'получение',
#   '«',
#   '’',
#   '»',
#   'процесс',
#   'решение',
#   'далее',
#   'примерно',
#   'равнозначный',
#   'вариант',
#   'вариант',
#   'самый',
#   'простой',
#   'идеальный',
#   'вариант',
#   'являться',
#   'отправка',
#   'почта',
#   'сразу',
#   'дополнительный',
#   'сервер',
#   'попробовать',
#   'теперь',
#   'попытка',
#   'отсылка',
#   'письмо',
#   'возвращать',
#   'следующий',
#   'ошибка',
#   '«',
#   '»',
#   'я',
#   'сходить',
#   'документация',
#   '’',
#   'попробовать',
#   'другой',
#   'порт',
#   'попробовать',
#   'также',
#   'установить',
#   'настройка',
#   'ящик',
#   'работа',
#   'в',
#   'результат',
#   'сообщение',
#   'ошибка',
#   'меняться',
#   'почта',
#   'уходить',
#   'поиск',
#   'интернет',
#   'указать',
#   'несколько',
#   'момент',
#   'требовать',
#   'использование',
#   'другой',
#   'название',
#   'поддерживать',
#   'особо',
#   'упорный',
#   'товарищ',
#   'пробовать',
#   'использовать',
#   'пакет',
#   'команда',
#   'потерпеть',
#   'фиаско',
#   'где',
#   'документация',
#   'найти',
#   'поддерживаться',
#   'оракл',
#   'начинать',
#   'версия',
#   'общий',
#   'мнение',
#   'сообщество',
#   'сводиться',
#   'следующий',
#   'использовать',
#   'морочить',
#   'голова',
#   'если',
#   'хотеть',
#   'использовать',
#   'поставить',
#   'проксить',
#   'вариант',
#   'описать',
#   'начало',
#   'статья',
#   'если',
#   'понимать',
#   'делать',
#   'мочь',
#   'попытаться',
#   'авторизоваться',
#   'почтовый',
#   'сервер',
#   'пакет',
#   'я',
#   'решить',
#   'попробовать',
#   'реализовать',
#   'пункт',
#   '–',
#   'искать',
#   'почтовый',
#   'сервер',
#   'находить',
#   'настройка',
#   'делать',
#   'пытаться',
#   'послать',
#   'письмо',
#   'получать',
#   'ошибка',
#   '«',
#   'временной',
#   'ошибка',
#   '»',
#   'перечитывать',
#   'настройка',
#   'пытаться',
#   'подключить',
#   'вариант',
#   'использование',
#   'авторизация',
#   'пакет',
#   'обсуждение',
#   'вариант',
#   'посмотреть',
#   'например',
#   'ничего',
#   'работать',
#   'почтовик',
#   'постоянно',
#   'закрывать',
#   'браузер',
#   'вкладка',
#   'описание',
#   'знать',
#   'количество',
#   'потенциально',
#   'полезный',
#   'стремиться',
#   'бесконечность',
#   'понимать',
#   'пора',
#   'это',
#   'заканчивать',
#   'время',
#   'очередной',
#   'поиск',
#   'находить',
#   'простой',
#   'мысль',
#   'закрытый',
#   'порт',
#   'проверять',
#   'оказываться',
#   'уметь',
#   'это',
#   'делать',
#   '–',
#   'закрытый',
#   'делать',
#   'указание',
#   'мой',
#   'альтернативный',
#   'почтовый',
#   'сервер',
#   'порт',
#   'пробовать',
#   'отправить',
#   'письмо',
#   'помощь',
#   'получать',
#   'ошибка',
#   '«',
#   'постоянный',
#   'ошибка',
#   '»',
#   'почти',
#   'получиться',
#   'избавляться',
#   'имя',
#   'отправитель',
#   'необходимый',
#   '’',
#   'письмо',
#   'уходить',
#   'заключение',
#   'в',
#   'статья',
#   'описать',
#   'свой',
#   'опыт',
#   'работа',
#   'отправка',
#   'почта',
#   'полевой',
#   'условие',
#   'отсутствие',
#   'необходимый',
#   'знание',
#   'работа',
#   'почтовый',
#   'сервер',
#   'получить',
#   'результат',
#   'являться',
#   'вполне',
#   'удовлетворительный',
#   'поскольку',
#   'найти',
#   '«дырявый»',
#   'почтовый',
#   'сервер',
#   'ранее',
#   'установленный',
#   'я',
#   'проксить',
#   'потратить',
#   'минута',
#   'выяснить',
#   'мочь',
#   'отправить',
#   'письмо',
#   'имя',
#   'любой',
#   'существующий',
#   'почтовый',
#   'сервер',
#   'ящик',
#   'просто',
#   'указать',
#   'например',
#   'вася',
#   'пупкина',
#   'имя',
#   'найти',
#   'почтовый',
#   'сервер',
#   'однако',
#   'свой',
#   'задача',
#   'решить',
#   'дырявый',
#   'проксить',
#   'необходимость',
#   'разбираться',
#   'настройка',
#   'избавиться',
#   'узнать',
#   'немного',
#   'пакет',
#   'также',
#   'планировать',
#   'разобраться',
#   'вариант',
#   'сходу',
#   'выйти',
#   'решить',
#   'тратить',
#   'время',
#   'добить',
#   'таки',
#   'отправка',
#   'письмо',
#   'напрямую',
#   'интересно',
#   'это',
#   'почитать',
#   'на',
#   'перенастройка',
#   'отправление',
#   'почта',
#   'обнаружение',
#   'спам',
#   'параллельный',
#   'написание',
#   'статья',
#   'потратить',
#   'около',
#   'час',
#   'Как',
#   'я',
#   'спам',
#   'слал',
#   'Oracle',
#   'Oracle',
#   'Как',
#   'я',
#   'спам',
#   'слал',
#   'Oracle',
#   'Oracle'],
#  ['вопрос',
#   'планирование',
#   'нагрузка',
#   'следовать',
#   'решать',
#   'ещё',
#   'ранний',
#   'стадия',
#   'развитие',
#   'любой',
#   'веб',
#   'проект',
#   '«падение»',
#   'сервер',
#   'оно',
#   'происходить',
#   'неожиданно',
#   'самый',
#   'неподходящий',
#   'момент',
#   'чреватый',
#   'весьма',
#   'серьёзный',
#   'последствие',
#   'моральный',
#   'материальный',
#   'первоначально',
#   'проблема',
#   'недостаточный',
#   'производительность',
#   'сервер',
#   'связь',
#   'рост',
#   'нагрузка',
#   'решать',
#   'путём',
#   'наращивание',
#   'мощность',
#   'сервер',
#   'оптимизация',
#   'использовать',
#   'алгоритм',
#   'программный',
#   'код',
#   'далее',
#   'но',
#   'рано',
#   'поздно',
#   'наступать',
#   'момент',
#   'мера',
#   'оказываться',
#   'недостаточный',
#   'приходиться',
#   'прибегать',
#   'кластеризация',
#   'несколько',
#   'сервер',
#   'объединяться',
#   'кластер',
#   'нагрузка',
#   'они',
#   'распределяться',
#   'помощь',
#   'комплекс',
#   'специальный',
#   'метод',
#   'называть',
#   'балансировка',
#   'помимо',
#   'решение',
#   'проблема',
#   'высокий',
#   'нагрузка',
#   'кластеризация',
#   'помогать',
#   'также',
#   'обеспечить',
#   'резервирование',
#   'сервер',
#   'друг',
#   'друг',
#   'эффективность',
#   'кластеризация',
#   'напрямую',
#   'зависеть',
#   'распределяться',
#   'балансироваться',
#   'нагрузка',
#   'элемент',
#   'кластер',
#   'балансировка',
#   'нагрузка',
#   'осуществляться',
#   'помощь',
#   'аппаратный',
#   'программный',
#   'инструмент',
#   'о',
#   'основный',
#   'метод',
#   'алгоритм',
#   'балансировка',
#   'хотеть',
#   'рассказать',
#   'статья',
#   'уровень',
#   'балансировка',
#   'процедура',
#   'балансировка',
#   'осуществляться',
#   'помощь',
#   'целое',
#   'комплекс',
#   'алгоритм',
#   'метод',
#   'соответствовать',
#   'следующий',
#   'уровень',
#   'модель',
#   'сетевой',
#   'транспортный',
#   'прикладной',
#   'рассмотреть',
#   'уровень',
#   'подробно',
#   'балансировка',
#   'сетевой',
#   'уровень',
#   'балансировка',
#   'сетевой',
#   'уровень',
#   'предполагать',
#   'решение',
#   'следующий',
#   'задача',
#   'нужно',
#   'сделать',
#   'конкретный',
#   'адрес',
#   'сервер',
#   'отвечать',
#   'разный',
#   'физический',
#   'машина',
#   'такой',
#   'балансировка',
#   'осуществляться',
#   'помощь',
#   'множество',
#   'разнообразный',
#   'способ',
#   'балансировка',
#   'на',
#   'один',
#   'доменный',
#   'имя',
#   'выделяться',
#   'несколько',
#   'адрес',
#   'сервер',
#   'который',
#   'направить',
#   'клиентский',
#   'запрос',
#   'обычно',
#   'определяться',
#   'помощь',
#   'алгоритм',
#   'метод',
#   'алгоритм',
#   'балансировка',
#   'подробно',
#   'рассказать',
#   'ниже',
#   'построение',
#   'кластер',
#   'при',
#   'использование',
#   'способ',
#   'сервер',
#   'объединяться',
#   'кластер',
#   'состоять',
#   'входной',
#   'вычислительный',
#   'узел',
#   'распределение',
#   'нагрузка',
#   'осуществляться',
#   'помощь',
#   'специальный',
#   'алгоритм',
#   'использоваться',
#   'решение',
#   'компания',
#   'балансировка',
#   'использование',
#   'дополнительный',
#   'маршрутизатор',
#   'балансировка',
#   'территориальный',
#   'признак',
#   'осуществляться',
#   'путём',
#   'размещение',
#   'одинаковый',
#   'сервис',
#   'одинаковый',
#   'адрес',
#   'территориально',
#   'различный',
#   'регион',
#   'интернет',
#   'работать',
#   'технология',
#   'который',
#   'писать',
#   'балансировка',
#   'территориальный',
#   'признак',
#   'также',
#   'использоваться',
#   'многий',
#   'смотреть',
#   'интересный',
#   'пример',
#   'реализация',
#   'балансировка',
#   'транспортный',
#   'уровень',
#   'этот',
#   'вид',
#   'балансировка',
#   'являться',
#   'самый',
#   'простой',
#   'клиент',
#   'обращаться',
#   'балансировщик',
#   'перенаправлять',
#   'запрос',
#   'один',
#   'сервер',
#   'который',
#   'обрабатывать',
#   'выбор',
#   'сервер',
#   'который',
#   'обрабатываться',
#   'запрос',
#   'осуществляться',
#   'соответствие',
#   'самый',
#   'разный',
#   'алгоритм',
#   'ещё',
#   'пойти',
#   'речь',
#   'ниже',
#   'путём',
#   'простой',
#   'круговой',
#   'перебор',
#   'путём',
#   'выбор',
#   'наименее',
#   'загрузить',
#   'сервер',
#   'пул',
#   'так',
#   'п',
#   'иногда',
#   'балансировка',
#   'транспортный',
#   'уровень',
#   'сложно',
#   'отличить',
#   'балансировка',
#   'сетевой',
#   'уровень',
#   'рассмотреть',
#   'следующий',
#   'правило',
#   'сетевой',
#   'фильтр',
#   'система',
#   'например',
#   'формально',
#   'идти',
#   'речь',
#   'балансировка',
#   'трафик',
#   'конкретный',
#   'порт',
#   'пример',
#   'сетевой',
#   'фильтр',
#   'система',
#   'речь',
#   'он',
#   'идти',
#   'балансировка',
#   'трафик',
#   'конкретный',
#   'порт',
#   'рассмотреть',
#   'пример',
#   '\\',
#   '\\',
#   'в',
#   'правило',
#   'речь',
#   'балансировка',
#   'исходящий',
#   'трафик',
#   'сетевой',
#   'уровень',
#   'в',
#   'он',
#   'указать',
#   'конкретный',
#   'порт',
#   'конкретный',
#   'протокол',
#   'различие',
#   'уровень',
#   'балансировка',
#   'объяснить',
#   'следующий',
#   'образ',
#   'к',
#   'сетевой',
#   'уровень',
#   'относиться',
#   'решение',
#   'который',
#   'терминировать',
#   'пользовательский',
#   'сессия',
#   'они',
#   'просто',
#   'перенаправлять',
#   'трафик',
#   'работать',
#   'проксировать',
#   'режим',
#   'на',
#   'сетевой',
#   'уровень',
#   'балансировщик',
#   'просто',
#   'решать',
#   'сервер',
#   'передавать',
#   'пакет',
#   'сессия',
#   'клиент',
#   'осуществлять',
#   'сервер',
#   'на',
#   'транспортный',
#   'уровена',
#   'общение',
#   'клиент',
#   'замыкаться',
#   'балансировщик',
#   'который',
#   'работать',
#   'проксить',
#   'он',
#   'взаимодействовать',
#   'сервер',
#   'свой',
#   'имя',
#   'передавать',
#   'информация',
#   'клиент',
#   'дополнительный',
#   'данные',
#   'заголовок',
#   'такой',
#   'образ',
#   'работать',
#   'например',
#   'популярный',
#   'программный',
#   'балансировщик',
#   'балансировка',
#   'прикладной',
#   'уровень',
#   'при',
#   'балансировка',
#   'прикладной',
#   'уровень',
#   'балансировщик',
#   'работать',
#   'режим',
#   '«умный',
#   'прокси»',
#   'он',
#   'анализировать',
#   'клиентский',
#   'запрос',
#   'перенаправлять',
#   'разный',
#   'сервер',
#   'зависимость',
#   'характер',
#   'запрашивать',
#   'контент',
#   'так',
#   'работать',
#   'например',
#   'веб',
#   'сервер',
#   'распределять',
#   'запрос',
#   'фронтенд',
#   'бэкендом',
#   'за',
#   'балансировка',
#   'отвечать',
#   'модуль',
#   'более',
#   'подробно',
#   'особенность',
#   'балансировка',
#   'основа',
#   'различный',
#   'алгоритм',
#   'прочитать',
#   'например',
#   'в',
#   'качество',
#   'ещё',
#   'один',
#   'пример',
#   'инструмент',
#   'балансировка',
#   'прикладной',
#   'уровень',
#   'привести',
#   'промежуточный',
#   'слой',
#   'клиент',
#   'сервер',
#   'субд',
#   'с',
#   'помощь',
#   'распределять',
#   'запрос',
#   'оп',
#   'сервер',
#   'база',
#   'данные',
#   'зависимость',
#   'содержание',
#   'например',
#   'запрос',
#   'чтение',
#   'быть',
#   'передаваться',
#   'сервер',
#   'запрос',
#   'запись',
#   'подробный',
#   'специфика',
#   'работа',
#   'почитать',
#   'статья',
#   'алгоритм',
#   'метод',
#   'балансировка',
#   'существовать',
#   'различный',
#   'алгоритм',
#   'метод',
#   'балансировка',
#   'нагрузка',
#   'выбирать',
#   'конкретный',
#   'алгоритм',
#   'нужно',
#   'исходить',
#   'первый',
#   'специфика',
#   'конкретный',
#   'проект',
#   'второй',
#   'цель',
#   'который',
#   'планировать',
#   'достигнуть',
#   'в',
#   'число',
#   'цель',
#   'достижение',
#   'который',
#   'использоваться',
#   'балансировка',
#   'нужно',
#   'выделить',
#   'следующий',
#   'справедливость',
#   'нужно',
#   'гарантировать',
#   'обработка',
#   'каждый',
#   'запрос',
#   'выделяться',
#   'системный',
#   'ресурс',
#   'допустить',
#   'возникновение',
#   'ситуация',
#   'запрос',
#   'обрабатываться',
#   'остальной',
#   'ждать',
#   'свой',
#   'очередь',
#   'эффективность',
#   'сервер',
#   'который',
#   'обрабатывать',
#   'запрос',
#   'должный',
#   'занятый',
#   'желательно',
#   'допускать',
#   'ситуация',
#   'сервер',
#   'простаивать',
#   'ожидание',
#   'запрос',
#   'обработка',
#   'сразу',
#   'оговориться',
#   'реальный',
#   'практика',
#   'этот',
#   'цель',
#   'достигаться',
#   'далеко',
#   'сокращение',
#   'время',
#   'выполнение',
#   'запрос',
#   'нужно',
#   'обеспечить',
#   'минимальный',
#   'время',
#   'начало',
#   'обработка',
#   'запрос',
#   'постановка',
#   'очередь',
#   'обработка',
#   'завершение',
#   'сокращение',
#   'время',
#   'отклик',
#   'нужно',
#   'минимизировать',
#   'время',
#   'ответ',
#   'запрос',
#   'пользователь',
#   'очень',
#   'желательно',
#   'также',
#   'алгоритм',
#   'балансировка',
#   'обладать',
#   'следующий',
#   'свойство',
#   'предсказуемость',
#   'нужно',
#   'чётко',
#   'понимать',
#   'какой',
#   'ситуация',
#   'какой',
#   'нагрузка',
#   'алгоритм',
#   'эффективный',
#   'решение',
#   'поставить',
#   'задача',
#   'равномерный',
#   'загрузка',
#   'ресурс',
#   'система',
#   'масштабирумость',
#   'алгоритм',
#   'должный',
#   'сохранять',
#   'работоспособность',
#   'увеличение',
#   'нагрузка',
#   'алгоритм',
#   'круговой',
#   'обслуживание',
#   'представлять',
#   'себя',
#   'перебор',
#   'круговой',
#   'цикл',
#   'первый',
#   'запрос',
#   'передаваться',
#   'один',
#   'сервер',
#   'затем',
#   'следующий',
#   'запрос',
#   'передаваться',
#   'другой',
#   'достижение',
#   'последний',
#   'сервер',
#   'затем',
#   'всё',
#   'начинаться',
#   'сначала',
#   'сам',
#   'распространёный',
#   'имплементация',
#   'алгоритм',
#   'являться',
#   'метод',
#   'балансировка',
#   'как',
#   'известно',
#   'любой',
#   'сервер',
#   'хранить',
#   'пара',
#   '«имя',
#   'хост',
#   'адрес»',
#   'каждый',
#   'машина',
#   'определённый',
#   'домен',
#   'этот',
#   'список',
#   'выглядеть',
#   'например',
#   'с',
#   'каждый',
#   'имя',
#   'список',
#   'ассоциировать',
#   'несколько',
#   'адрес',
#   'сервер',
#   'проходить',
#   'весь',
#   'запись',
#   'таблица',
#   'отдавать',
#   'каждый',
#   'новый',
#   'запрос',
#   'следующий',
#   'адрес',
#   'например',
#   'первый',
#   'запрос',
#   'второй',
#   'ххх',
#   'ххх',
#   'ххх',
#   'далее',
#   'в',
#   'результат',
#   'сервер',
#   'кластер',
#   'получать',
#   'одинаковый',
#   'количество',
#   'запрос',
#   'в',
#   'число',
#   'несомненный',
#   'плюс',
#   'алгоритм',
#   'следовать',
#   'назвать',
#   'первый',
#   'независимость',
#   'протокол',
#   'высокий',
#   'уровень',
#   'для',
#   'работа',
#   'алгоритм',
#   'использоваться',
#   'любой',
#   'протокол',
#   'который',
#   'обращение',
#   'сервер',
#   'идти',
#   'имя',
#   'балансировка',
#   'основа',
#   'алгоритм',
#   'никак',
#   'зависеть',
#   'нагрузка',
#   'сервер',
#   'кэшировать',
#   'сервер',
#   'помочь',
#   'справиться',
#   'любой',
#   'наплыв',
#   'клиент',
#   'использование',
#   'алгоритм',
#   'требовать',
#   'связь',
#   'сервер',
#   'поэтому',
#   'использоваться',
#   'локальный',
#   'глобальный',
#   'балансировка',
#   'наконец',
#   'решение',
#   'база',
#   'алгоритм',
#   'отличаться',
#   'низкий',
#   'стоимость',
#   'начать',
#   'работать',
#   'достаточно',
#   'просто',
#   'добавить',
#   'несколько',
#   'запись',
#   'алгоритм',
#   'иметь',
#   'целый',
#   'ряд',
#   'существенный',
#   'недостаток',
#   'недостаток',
#   'чтобы',
#   'распределение',
#   'нагрузка',
#   'этот',
#   'алгоритм',
#   'отвечать',
#   'упомянуть',
#   'выше',
#   'критерий',
#   'справедливость',
#   'эффективность',
#   'нужно',
#   'каждый',
#   'сервер',
#   'наличие',
#   'одинаковый',
#   'набор',
#   'ресурс',
#   'при',
#   'выполнение',
#   'операция',
#   'также',
#   'должный',
#   'задействовать',
#   'одинаковый',
#   'количество',
#   'ресурс',
#   'в',
#   'реальный',
#   'практика',
#   'условие',
#   'большинство',
#   'случай',
#   'оказываться',
#   'невыполнимый',
#   'также',
#   'балансировка',
#   'алгоритм',
#   'совершенно',
#   'учитываться',
#   'загруженность',
#   'иной',
#   'сервер',
#   'состав',
#   'кластер',
#   'представимый',
#   'следующий',
#   'гипотетический',
#   'ситуация',
#   'узел',
#   'загрузить',
#   'время',
#   'другой',
#   'алгоритм',
#   'возможность',
#   'возникновение',
#   'ситуация',
#   'учитывать',
#   'принцип',
#   'поэтому',
#   'перегрузить',
#   'узел',
#   'равно',
#   'получать',
#   'запрос',
#   'ни',
#   'справедливость',
#   'эффективность',
#   'предсказуемость',
#   'такой',
#   'случай',
#   'речь',
#   'в',
#   'сила',
#   'описать',
#   'выше',
#   'обстоятельство',
#   'сфера',
#   'применение',
#   'алгоритм',
#   'весьма',
#   'ограничить',
#   'это',
#   'усовершенствовать',
#   'версия',
#   'алгоритм',
#   'быть',
#   'усовершенствование',
#   'заключаться',
#   'следующий',
#   'каждый',
#   'сервер',
#   'присваиваться',
#   'весовой',
#   'коэффициент',
#   'соответствие',
#   'производительность',
#   'мощность',
#   'это',
#   'помогать',
#   'распределять',
#   'нагрузка',
#   'гибко',
#   'сервер',
#   'больший',
#   'вес',
#   'обрабатывать',
#   'запрос',
#   'однако',
#   'проблема',
#   'отказоустойчивость',
#   'это',
#   'отнюдь',
#   'решать',
#   'более',
#   'эффективный',
#   'балансировка',
#   'обеспечивать',
#   'другой',
#   'метод',
#   'который',
#   'планирование',
#   'распределение',
#   'нагрузка',
#   'учитываться',
#   'больший',
#   'количество',
#   'параметр',
#   'в',
#   'предыдущий',
#   'раздел',
#   'перечислить',
#   'основной',
#   'недостаток',
#   'алгоритм',
#   'назвать',
#   'ещё',
#   'он',
#   'совершенно',
#   'учитываться',
#   'количество',
#   'активный',
#   'данный',
#   'момент',
#   'подключение',
#   'рассмотреть',
#   'практический',
#   'пример',
#   'иметься',
#   'сервер',
#   'обозначить',
#   'условно',
#   'а',
#   'б',
#   'к',
#   'сервер',
#   'а',
#   'подключить',
#   'маленький',
#   'пользователь',
#   'сервер',
#   'б',
#   'при',
#   'сервер',
#   'а',
#   'оказываться',
#   'перегрузить',
#   'как',
#   'это',
#   'возможно',
#   'ответ',
#   'достаточно',
#   'простой',
#   'подключение',
#   'сервер',
#   'а',
#   'поддерживаться',
#   'течение',
#   'долгий',
#   'время',
#   'сравнение',
#   'подключение',
#   'сервер',
#   'б',
#   'описать',
#   'проблема',
#   'решить',
#   'помощь',
#   'алгоритм',
#   'известный',
#   'название',
#   'сокращённо',
#   'он',
#   'учитывать',
#   'количество',
#   'подключение',
#   'поддерживать',
#   'сервер',
#   'текущий',
#   'момент',
#   'время',
#   'каждый',
#   'следующий',
#   'вопрос',
#   'передаваться',
#   'сервер',
#   'малый',
#   'количество',
#   'активный',
#   'подключение',
#   'существовать',
#   'усовершенствовать',
#   'вариант',
#   'алгоритм',
#   'предназначить',
#   'первый',
#   'очередь',
#   'использование',
#   'кластер',
#   'состоять',
#   'сервер',
#   'разный',
#   'технический',
#   'характеристика',
#   'разный',
#   'производительность',
#   'он',
#   'называться',
#   'учитывать',
#   'распределение',
#   'нагрузка',
#   'количество',
#   'активный',
#   'подключение',
#   'весовой',
#   'коэффициент',
#   'сервер',
#   'в',
#   'число',
#   'другой',
#   'усовершенствовать',
#   'вариант',
#   'алгоритм',
#   'следовать',
#   'прежде',
#   'выделить',
#   'первый',
#   'метод',
#   ...],
#  ['дрон',
#   'активно',
#   'применяться',
#   'съёмка',
#   'высота',
#   'также',
#   'перспектива',
#   'рассмотреть',
#   'оборонный',
#   'промышленность',
#   'однако',
#   'область',
#   'применение',
#   'коптер',
#   'постоянно',
#   'расширяться',
#   'рассказывать',
#   'сфера',
#   'деятельность',
#   'мочь',
#   'прижиться',
#   'роботизированный',
#   'установка',
#   'судить',
#   'количество',
#   'разнообразие',
#   'профессия',
#   'смена',
#   'который',
#   'мочь',
#   'прийти',
#   'бпнуть',
#   'сказать',
#   'эра',
#   'дрон',
#   'наступить',
#   'дрон',
#   'раскопщик',
#   'в',
#   'прошлый',
#   'год',
#   'квадрокоптер',
#   'смочь',
#   'обнаружить',
#   'древний',
#   'поселение',
#   'мексика',
#   'случиться',
#   'это',
#   'робот',
#   'повесить',
#   'тепловизор',
#   'показать',
#   'местонахождение',
#   'холодный',
#   'участок',
#   'песок',
#   'археолог',
#   'смочь',
#   'найти',
#   'древний',
#   'захоронение',
#   'также',
#   'тепловизор',
#   'установить',
#   'вертолёт',
#   'крупный',
#   'город',
#   'украина',
#   'помогать',
#   'отслеживать',
#   'прорыв',
#   'теплотрасса',
#   'дрон',
#   'помощник',
#   'мкс',
#   'в',
#   'прошлый',
#   'год',
#   'специалист',
#   'решить',
#   'совместно',
#   'заняться',
#   'создание',
#   'автономный',
#   'дрон',
#   'помощник',
#   'который',
#   'быть',
#   'помогать',
#   'астронавт',
#   'быт',
#   'этот',
#   'дрон',
#   'иметь',
#   'форма',
#   'сфера',
#   'предназначить',
#   'работа',
#   'невесомость',
#   'благодаря',
#   'разработка',
#   'область',
#   'реальность',
#   'человек',
#   'мочь',
#   'создать',
#   'модель',
#   'окружающий',
#   'пространство',
#   'счёт',
#   'навигация',
#   'бот',
#   'становиться',
#   'значительно',
#   'простой',
#   'дрон',
#   'раздача',
#   'интернет',
#   'в',
#   'прошлый',
#   'год',
#   'сразу',
#   'интернет',
#   'гигант',
#   'объявить',
#   'свой',
#   'решение',
#   'создать',
#   'сеть',
#   'который',
#   'смочь',
#   'покрыть',
#   'планета',
#   'в',
#   'март',
#   'марк',
#   'цукерберг',
#   'изъявить',
#   'желание',
#   'купить',
#   'компания',
#   'который',
#   'заниматься',
#   'создание',
#   'дрон',
#   'солнечный',
#   'батарея',
#   'спустя',
#   'месяц',
#   'поступить',
#   'сообщение',
#   'приобретение',
#   'похожий',
#   'компания',
#   'также',
#   'ит',
#   'гигант',
#   'заявить',
#   'желание',
#   'образовать',
#   'сеть',
#   'спутник',
#   'лазер',
#   'дрон',
#   'который',
#   'образовать',
#   'интернет',
#   'покрытие',
#   'весь',
#   'планета',
#   'месяц',
#   'спустя',
#   'компания',
#   'сообщить',
#   'приобретение',
#   'подобный',
#   'компания',
#   'план',
#   'создать',
#   'связка',
#   'сеть',
#   'спутник',
#   'лазер',
#   'дрон',
#   'который',
#   'смочь',
#   'обеспечить',
#   'интернет',
#   'покрытие',
#   'земля',
#   'в',
#   'итог',
#   'ит',
#   'гигант',
#   'стать',
#   'владелец',
#   'бренд',
#   'это',
#   'должный',
#   'обеспечить',
#   'подключение',
#   'интернет',
#   'труднодоступный',
#   'участок',
#   'планета',
#   'робот',
#   'солнечный',
#   'батарея',
#   'успех',
#   'использоваться',
#   'год',
#   'поэтому',
#   'достижение',
#   'цель',
#   'остаться',
#   'научить',
#   'летать',
#   'оснастить',
#   'мощный',
#   'передатчик',
#   'нужный',
#   'количество',
#   'спутник',
#   'присутствовать',
#   'орбита',
#   'дрон',
#   'скорый',
#   'помощь',
#   'дрон',
#   'иметь',
#   'вид',
#   'небольшой',
#   'квадрокоптер',
#   'это',
#   'очередной',
#   'подтвердить',
#   'массачусетский',
#   'технологический',
#   'институт',
#   'разработать',
#   'минь',
#   'вертолёт',
#   'который',
#   'управлять',
#   'удалённый',
#   'основа',
#   'этот',
#   'дрон',
#   'доставить',
#   'лекарство',
#   'припас',
#   'труднодоступный',
#   'территория',
#   'планета',
#   'такой',
#   'транспортировка',
#   'обойтись',
#   'раз',
#   'дешёвый',
#   'нежели',
#   'использование',
#   'другой',
#   'вид',
#   'транспорт',
#   'вертолёт',
#   'автомобиль',
#   'дрон',
#   'доставщик',
#   'недавно',
#   'сми',
#   'появиться',
#   'информация',
#   'дрон',
#   'быть',
#   'задействовать',
#   'цель',
#   'доставка',
#   'заказ',
#   'пока',
#   'оба',
#   'компания',
#   'активно',
#   'искать',
#   'способ',
#   'справиться',
#   'законодательный',
#   'запрет',
#   'исключить',
#   'это',
#   'удаться',
#   'поскольку',
#   'решение',
#   'задача',
#   'подключиться',
#   'дрон',
#   'перемещать',
#   'товар',
#   'активно',
#   'доставлять',
#   'пицца',
#   'они',
#   'задействовать',
#   'один',
#   'самый',
#   'крупный',
#   'пиццерия',
#   'мир',
#   'у',
#   'собственный',
#   'домикоптер',
#   'появиться',
#   'год',
#   'назад',
#   'с',
#   'момент',
#   'технология',
#   'стать',
#   'развитой',
#   'исключить',
#   'близкий',
#   'будущее',
#   'такой',
#   'скоростной',
#   'доставка',
#   'стать',
#   'реальность',
#   'дрон',
#   'санэпидемиолог',
#   'этот',
#   'дрон',
#   'задействовать',
#   'строительство',
#   'конкретный',
#   'начало',
#   'робот',
#   'исследовать',
#   'строительный',
#   'площадка',
#   'предмет',
#   'соблюсти',
#   'санитарный',
#   'эпидемиологический',
#   'требование',
#   'норматив',
#   'иной',
#   'уровень',
#   'высота',
#   'к',
#   'тот',
#   'площадка',
#   'измерить',
#   'уровень',
#   'электромагнитный',
#   'радиоактивный',
#   'излучение',
#   'с',
#   'помощь',
#   'дрон',
#   'обследовать',
#   'расположить',
#   'вблизи',
#   'территория',
#   'измерять',
#   'уровень',
#   'шум',
#   'излучение',
#   'тот',
#   'иной',
#   'высота',
#   'дрон',
#   'рекламист',
#   'опыт',
#   'применение',
#   'беспилотный',
#   'летать',
#   'машина',
#   'реклама',
#   'иметь',
#   'азиатский',
#   'сеть',
#   'ресторан',
#   'который',
#   'креативный',
#   'рекламный',
#   'агентство',
#   'выпустить',
#   'дрон',
#   'летать',
#   'баннер',
#   'увидеть',
#   'вокруг',
#   'бизнес',
#   'центр',
#   'обеденный',
#   'время',
#   'зазывать',
#   'голодный',
#   '«белых',
#   'воротничков»',
#   'посетить',
#   'заведение',
#   'дрон',
#   'официант',
#   'в',
#   'сингапур',
#   'беспилотный',
#   'летательный',
#   'аппарат',
#   'помогать',
#   'справиться',
#   'дефицит',
#   'обслуживающий',
#   'персонал',
#   'заведение',
#   'общепит',
#   'для',
#   'управление',
#   'дрон',
#   'использоваться',
#   'компьютерный',
#   'программа',
#   'ориентироваться',
#   'пространство',
#   'позволять',
#   'инфракрасный',
#   'датчик',
#   'вдобавок',
#   'к',
#   'весь',
#   'комплект',
#   'каждый',
#   'устройство',
#   'входить',
#   'камера',
#   'винт',
#   'защитный',
#   'решётка',
#   'планироваться',
#   'дрон',
#   'появиться',
#   'один',
#   'местный',
#   'бар',
#   'конец',
#   'год',
#   'быть',
#   'переносить',
#   'два',
#   'килограмм',
#   'еда',
#   'напиток',
#   'а',
#   'лондонский',
#   'ресторанчик',
#   'дрон',
#   'успешно',
#   'заменять',
#   'латать',
#   'поднос',
#   'здешний',
#   'официант',
#   'перемещаться',
#   'столик',
#   'столик',
#   'управлять',
#   'беспилотный',
#   'летательный',
#   'аппарат',
#   'приложение',
#   'дрон',
#   'патрульный',
#   'многие',
#   'страна',
#   'год',
#   'вести',
#   'активный',
#   'борьба',
#   'незаконный',
#   'иммиграция',
#   'также',
#   'пиратство',
#   'терроризм',
#   'применение',
#   'беспилотный',
#   'летательный',
#   'аппарат',
#   'предоставить',
#   'серьёзный',
#   'помощь',
#   'решение',
#   'этот',
#   'проблема',
#   'например',
#   'полиция',
#   'пограничный',
#   'орган',
#   'австралия',
#   'активно',
#   'использовать',
#   'беспилотник',
#   'обеспечить',
#   'безопасность',
#   'побережье',
#   'они',
#   'пример',
#   'скорый',
#   'время',
#   'собираться',
#   'последовать',
#   'индия',
#   'в',
#   'условие',
#   'потенциальный',
#   'тендер',
#   'указать',
#   'аппарат',
#   'быть',
#   'использоваться',
#   'дневный',
#   'ночной',
#   'операция',
#   'актуальный',
#   'помощь',
#   'дрон',
#   'решение',
#   'вопрос',
#   'окружающий',
#   'среда',
#   'с',
#   'помощь',
#   'власть',
#   'мочь',
#   'следить',
#   'человек',
#   'загрязнять',
#   'природный',
#   'ресурс',
#   'отход',
#   'также',
#   'использовать',
#   'цель',
#   'исследование',
#   'озоновый',
#   'слой',
#   'дрон',
#   'фермер',
#   'в',
#   'сша',
#   'биолог',
#   'эпидемиолог',
#   'бить',
#   'тревога',
#   'страна',
#   'активно',
#   'снижаться',
#   'популяция',
#   'пчела',
#   'причём',
#   'пока',
#   'установить',
#   'происходить',
#   'это',
#   'вина',
#   'пестицид',
#   'паразит',
#   'какой',
#   'либо',
#   'другой',
#   'влияние',
#   'окружающий',
#   'среда',
#   'для',
#   'решение',
#   'проблема',
#   'сотрудник',
#   'гарвард',
#   'создать',
#   'робопчела',
#   'задача',
#   'который',
#   'превращать',
#   'энергия',
#   'движение',
#   'пьезоэлектрик',
#   'пока',
#   'этот',
#   'проект',
#   'сила',
#   'спасти',
#   'пчела',
#   'мир',
#   'иметь',
#   'ряд',
#   'ограничение',
#   'миниатюрный',
#   'пчела',
#   'привязать',
#   'проводы',
#   'источник',
#   'энергия',
#   'крохотный',
#   'телец',
#   'позволять',
#   'скорректировать',
#   'направление',
#   'движение',
#   'исключить',
#   'будущее',
#   'смочь',
#   'отличить',
#   'обычный',
#   'насекомое',
#   'роботизированный',
#   'аналог',
#   'также',
#   'дрон',
#   'использоваться',
#   'сельский',
#   'хозяйство',
#   'посадка',
#   'дерево',
#   'но',
#   'пока',
#   'всё',
#   'прекрасно',
#   'посадка',
#   'казаться',
#   'бывать',
#   'фэйл',
#   'дрон',
#   'тренер',
#   'специалист',
#   'австралийский',
#   'технологический',
#   'институт',
#   'флойда',
#   'мюллер',
#   'эберхард',
#   'гратереть',
#   'создать',
#   'дрон',
#   'который',
#   'стать',
#   'наш',
#   'личный',
#   'тренер',
#   'время',
#   'пробежка',
#   'он',
#   'сопровождать',
#   'человек',
#   'цель',
#   'задать',
#   'необходимый',
#   'ритм',
#   'также',
#   'устраивать',
#   'робот',
#   'соревнование',
#   'бег',
#   'с',
#   'помощь',
#   'специальный',
#   'программный',
#   'обеспечение',
#   'дрон',
#   'узнать',
#   'бегун',
#   'цвет',
#   'рисунок',
#   'одежда',
#   'чтобы',
#   'человек',
#   'возникать',
#   'чувство',
#   'преследование',
#   'создатель',
#   'позаботиться',
#   'лететь',
#   'впереди',
#   'бегун',
#   'дрон',
#   'винодел',
#   'бпнуть',
#   'стать',
#   'помощник',
#   'винодел',
#   'французский',
#   'регион',
#   'бордо',
#   'здесь',
#   'летать',
#   'робот',
#   'оснастить',
#   'камера',
#   'высокий',
#   'разрешение',
#   'контролировать',
#   'ситуация',
#   'земля',
#   'передавать',
#   'винодел',
#   'информация',
#   'какой',
#   'состояние',
#   'лоза',
#   'это',
#   'позволять',
#   'узнать',
#   'нужный',
#   'виноград',
#   'дополнительный',
#   'полить',
#   'подпитка',
#   'удобрение',
#   'дрон',
#   'также',
#   'иметь',
#   'инфракрасный',
#   'камера',
#   'определение',
#   'степень',
#   'зрелость',
#   'виноград',
#   'так',
#   'организовать',
#   'сбор',
#   'ягода',
#   'каждый',
#   'лоза',
#   'момент',
#   'оптимальный',
#   'зрелость',
#   'это',
#   'очень',
#   'важно',
#   'качество',
#   'вино',
#   'дрон',
#   'журналист',
#   'поскольку',
#   'летать',
#   'аппарат',
#   'способный',
#   'видеть',
#   'сверху',
#   'мочь',
#   'стать',
#   'отличный',
#   'помощник',
#   'работник',
#   'сми',
#   'это',
#   'понять',
#   'будущий',
#   'журналист',
#   'изучать',
#   'курс',
#   'управление',
#   'дрон',
#   'здесь',
#   'учить',
#   'использовать',
#   'бпнуть',
#   'сбор',
#   'информация',
#   'активный',
#   'опыт',
#   'использование',
#   'дрон',
#   'папарацци',
#   'который',
#   'такой',
#   'образ',
#   'получать',
#   'фото',
#   'видео',
#   'звезда',
#   'домашний',
#   'бассейн',
#   'также',
#   'беспилотник',
#   'задействовать',
#   'спортивный',
#   'журналистика',
#   'на',
#   'данный',
#   'момент',
#   'компания',
#   'заниматься',
#   'разработка',
#   'робот',
#   'который',
#   'использовать',
#   'съёмка',
#   'экстремальный',
#   'вид',
#   'спорт',
#   'такой',
#   'сноубординг',
#   'бейсджампинг',
#   'ралли',
#   'так',
#   'далее',
#   'дрон',
#   'охранник',
#   'дрон',
#   'встроить',
#   'видеокамера',
#   'датчик',
#   'который',
#   'реагировать',
#   'движение',
#   'тепло',
#   'электрошоковый',
#   'пистолет',
#   'заряд',
#   'вольт',
#   'заменить',
#   'пост',
#   'охранник',
#   'подобный',
#   'опыт',
#   'железнодорожный',
#   'компания',
#   'задействовать',
#   'дрон',
#   'узнать',
#   'испортить',
#   'вагон',
#   'поезд',
#   'помощь',
#   'граффити',
#   'для',
#   'этот',
#   'цель',
#   'закупить',
#   'дрон',
#   'который',
#   'летать',
#   'путь',
#   'высота',
#   'метр',
#   'спускаться',
#   'замечать',
#   'подозрительный',
#   'дрон',
#   'парка',
#   'развлечение',
#   'внедрять',
#   'дрон',
#   'свой',
#   'воздушный',
#   'представление',
#   'по',
#   'задумка',
#   'быть',
#   'задействовать',
#   'воздушный',
#   'кукла',
#   'марионетка',
#   'который',
#   'управляться',
#   'дрон',
#   'система',
#   'собираться',
#   'полностью',
#   'интегрировать',
#   'наземный',
#   'станция',
#   'управление',
#   'который',
#   'контролировать',
#   'полёт',
#   'устройство',
#   'течение',
#   'представление',
#   'работник',
#   'считать',
#   'это',
#   'позволить',
#   'избавиться',
#   'ограничение',
#   'который',
#   'воздушный',
#   'номер',
#   'также',
#   'летательный',
#   'аппарат',
#   'мочь',
#   'задействовать',
#   'праздник',
#   'корпоратив',
#   'устраивать',
#   'развлекательный',
#   'состязание',
#   'боевой',
#   'коптер',
#   '15',
#   'профессий',
#   'для',
#   'летающих',
#   'дронов',
#   'Блог',
#   'компании',
#   'RoboHunter',
#   'профессии',
#   '15',
#   'профессий',
#   'для',
#   'летающих',
#   'дронов',
#   'Блог',
#   'компании',
#   'RoboHunter',
#   'профессии'],
#  ['привет',
#   'для',
#   'сборник',
#   'ответ',
#   'часто',
#   'задавать',
#   'вопрос',
#   'решить',
#   'использовать',
#   'идея',
#   'поскольку',
#   'мы',
#   'казаться',
#   'смысл',
#   'писать',
#   'один',
#   'конкретный',
#   'человек',
#   'такой',
#   'сайт',
#   'хабрахабра',
#   'всё',
#   'равно',
#   'остаться',
#   'человек',
#   'который',
#   'остаться',
#   'вопрос',
#   'посему',
#   'обращаться',
#   'читатель',
#   'группа',
#   'следующий',
#   'вопрос',
#   'движок',
#   'доступный',
#   'ваш',
#   'идеально',
#   'подходить',
#   'составление',
#   '«коллективного»',
#   'чаво',
#   'сайт',
#   'Wiki-FAQ',
#   'для',
#   'Хабрахабра',
#   'Habr',
#   'хабрахаб',
#   'Wiki-FAQ',
#   'для',
#   'Хабрахабра',
#   'Habr',
#   'хабрахаб'],
#  ['содержаниеглав',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'вы',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'глава',
#   'эпилог',
#   '–',
#   'и',
#   'следующий',
#   'сутки',
#   'провести',
#   'бункер',
#   'доктор',
#   'взять',
#   'стол',
#   'очки',
#   'снова',
#   'надеть',
#   'затем',
#   'поднять',
#   'взгляд',
#   'райтновый',
#   '–',
#   'да',
#   'алекс',
#   'именно',
#   'я',
#   'спрятаться',
#   'один',
#   'спальный',
#   'место',
#   'комната',
#   'номер',
#   'он',
#   'запнуться',
#   'опустить',
#   'взгляд',
#   'стол',
#   'немой',
#   'написать',
#   'затем',
#   'продолжить',
#   '–…',
#   'действительно',
#   'стыдно',
#   'это',
#   'в',
#   'столовая',
#   'воцариться',
#   'тишина',
#   'лишь',
#   'доктор',
#   'тихонько',
#   'всхлипывать',
#   '–',
#   'ребёнок',
#   'готовый',
#   'заплакать',
#   'он',
#   'рассказать',
#   'хороший',
#   'история',
#   'райтновый',
#   'начать',
#   'сомневаться',
#   'обоснованность',
#   'свой',
#   'подозрение',
#   'говорить',
#   'правда',
#   'действительно',
#   'это',
#   'время',
#   'рядом',
#   'алекс',
#   'бросить',
#   'взгляд',
#   'гордон',
#   '–',
#   'монотонно',
#   'поглаживать',
#   'борода',
#   'правый',
#   'рука',
#   'задумчиво',
#   'смотреть',
#   'ангуса',
#   'барни',
#   'сидеть',
#   'хмурый',
#   'думать',
#   'лицо',
#   'невозможно',
#   'либо',
#   'определить',
#   'райтновый',
#   'снова',
#   'снова',
#   'воспроизводить',
#   'память',
#   'обыскивать',
#   'бункер',
#   '–',
#   'это',
#   'лишь',
#   'усиливать',
#   'сомнение',
#   'так',
#   'обычно',
#   'бывать',
#   'искать',
#   'какой',
#   'вещь',
#   'думать',
#   'стол',
#   'сам',
#   'себя',
#   'сам',
#   'дело',
#   'видеть',
#   'буквально',
#   'час',
#   'назад',
#   'выдвижной',
#   'ящик',
#   'стол',
#   '–',
#   'райтновый',
#   'мочь',
#   'вспомнить',
#   'проверять',
#   'спальная',
#   'место',
#   'каждый',
#   'комната',
#   'из',
#   'раздумье',
#   'вывести',
#   'мягкий',
#   'голос',
#   'эмилий',
#   '–',
#   'не',
#   'винить',
#   'ангус',
#   '–',
#   'виноватый',
#   'страх',
#   '–',
#   'это',
#   'древний',
#   'инстинкт',
#   'помогать',
#   'мы',
#   'выживать',
#   'помочь',
#   'вы',
#   'никак',
#   'мочь',
#   'помочь',
#   'свой',
#   'друг',
#   '–',
#   'я',
#   'повести',
#   '–',
#   'согласиться',
#   'айзек',
#   '–',
#   'едва',
#   'простой',
#   'учёный',
#   'вроде',
#   'мочь',
#   'либо',
#   'противопоставить',
#   'титан',
#   'ситуация',
#   'доктор',
#   'признательный',
#   'кивнуть',
#   'поднимать',
#   'взгляд',
#   'продолжить',
#   '–',
#   'весь',
#   'ночь',
#   'спасть',
#   'лишь',
#   'прислушиваться',
#   'иногда',
#   'казаться',
#   'слышать',
#   'приглушить',
#   'голос',
#   'крик',
#   'уверенный',
#   'настоящий',
#   'я',
#   'вполне',
#   'допускать',
#   'это',
#   'мозг',
#   'воспроизводить',
#   'крик',
#   'тот',
#   'бедняга',
#   'который',
#   'погибнуть',
#   'лаборатория',
#   '–',
#   'полный',
#   'ужас',
#   'крепко',
#   'въесться',
#   'мой',
#   'подсознание',
#   'райтновый',
#   'сделать',
#   'большой',
#   'глотка',
#   'капучиный',
#   'напиток',
#   'успеть',
#   'остыть',
#   'неприятно',
#   'обжечь',
#   'горло',
#   'поэтому',
#   'поморщиться',
#   'затем',
#   'задать',
#   'вопрос',
#   '–',
#   'я',
#   'допускать',
#   'мочь',
#   'заметить',
#   '–',
#   'действительно',
#   'смотреть',
#   'спальный',
#   'место',
#   'с',
#   'сторона',
#   '–',
#   'очень',
#   'компактный',
#   'они',
#   'тесновато',
#   'человек',
#   'ваш',
#   'доктор',
#   'телосложение',
#   'но',
#   'точно',
#   'помнить',
#   'следующий',
#   'день',
#   'обойти',
#   'комната',
#   'бункер',
#   'нарочно',
#   'громко',
#   'спрашивать',
#   'рядом',
#   'неужели',
#   'настолько',
#   'напугать',
#   'отозваться',
#   'голос',
#   'ангус',
#   'поправить',
#   'очки',
#   'снова',
#   'поднять',
#   'взгляд',
#   '–',
#   'я',
#   'согласный',
#   'это',
#   'выглядеть',
#   'странно',
#   'ваш',
#   'место',
#   'начать',
#   'подозревать',
#   'но',
#   'менее',
#   'мой',
#   'объяснение',
#   'простой',
#   '–',
#   'близкий',
#   'утро',
#   'вырубиться',
#   'попросту',
#   'слышать',
#   'а',
#   'проснуться',
#   'вечер',
#   '–',
#   'часы',
#   'показывать',
#   'такой',
#   'поздний',
#   'время',
#   'рискнуть',
#   'выходить',
#   'бояться',
#   'возвращение',
#   'вы',
#   'находить',
#   'мой',
#   'рассуждение',
#   'логичный',
#   'настать',
#   'очередь',
#   'райтновый',
#   'опустить',
#   'взгляд',
#   'он',
#   'кивнуть',
#   'согласиться',
#   '–',
#   'да',
#   'вернуться',
#   'бункер',
#   'час',
#   'поздний',
#   'рискнуть',
#   'высовываться',
#   'остальной',
#   'уехать',
#   'полдень',
#   'доктор',
#   'обратить',
#   'внимание',
#   'последний',
#   'фраза',
#   'продолжить',
#   '–',
#   'учитывать',
#   'поздний',
#   'час',
#   'отсутствие',
#   'вариант',
#   'действие',
#   'попытаться',
#   'снова',
#   'заснуть',
#   'судить',
#   'весь',
#   'это',
#   'удаться',
#   'довольно',
#   'скоро',
#   'слышать',
#   'вернуться',
#   'бункер',
#   'я',
#   'проснуться',
#   'около',
#   'час',
#   'утро',
#   'светло',
#   'заставить',
#   'выйти',
#   'направиться',
#   'столовая',
#   '–',
#   'очень',
#   'хотеться',
#   'пить',
#   'утолить',
#   'жажда',
#   'выйти',
#   'наружу',
#   'попытаться',
#   'понять',
#   'поступить',
#   'эмилия',
#   'встретиться',
#   'взгляд',
#   'доктор',
#   'увидеть',
#   'тот',
#   'сторона',
#   'линза',
#   'глаз',
#   'полный',
#   'неподдельный',
#   'ужас',
#   '–',
#   'не',
#   'стоить',
#   'переживать',
#   '–',
#   'сказать',
#   'тихий',
#   'спокойный',
#   'голос',
#   '–',
#   'позади',
#   'один',
#   'вместе',
#   'справиться',
#   'он',
#   'взгляд',
#   'немного',
#   'проясниться',
#   'быстро',
#   'нервно',
#   'закивать',
#   'затем',
#   'продолжить',
#   '–',
#   'когда',
#   'выйти',
#   'увидеть',
#   'кровь',
#   '–',
#   'кровь',
#   'но',
#   'касаться',
#   'трупов…',
#   'алекс',
#   'удаться',
#   'обнаружить',
#   'хотя',
#   '–',
#   'нет',
#   '–',
#   'как',
#   'всё',
#   'кровь',
#   'труп',
#   'нигде',
#   'найти',
#   'это',
#   'довольно',
#   'жуткий',
#   'делать',
#   'короткий',
#   'перебежка',
#   'добраться',
#   'жилой',
#   'корпус',
#   'который',
#   'счастливый',
#   'случайность',
#   'оказаться',
#   'нетронутый',
#   'проникнуть',
#   'комната',
#   'я',
#   'взять',
#   'планшет',
#   'сразу',
#   'сделать',
#   'несколько',
#   'запись',
#   '–',
#   'позволить',
#   'показать',
#   'один',
#   'ангус',
#   'достать',
#   'пазуха',
#   'свой',
#   'планшет',
#   'вывести',
#   'стол',
#   'проекция',
#   'запись',
#   'короткий',
#   'сказать',
#   'лишь',
#   'следующий',
#   '“я',
#   'обнаружить',
#   'интересный',
#   'факт',
#   '–',
#   'жилой',
#   'корпус',
#   'оказаться',
#   'нетронутый',
#   'судить',
#   'весь',
#   'титан',
#   'обладали…',
#   'простить',
#   'обладать',
#   'настолько',
#   'хороший',
#   'обоняние',
#   'стать',
#   'тратить',
#   'сила',
#   'вскрытие',
#   'пустой',
#   'коробка',
#   'тщетный',
#   'поиск',
#   'жертва',
#   '–',
#   'сконцентрироваться',
#   'тот',
#   'корпус',
#   'который',
#   'действительно',
#   'находиться',
#   'колонисты…',
#   'считать',
#   'разумны”',
#   'на',
#   'запись',
#   'закончиться',
#   'доктор',
#   'прикусить',
#   'губа',
#   'снова',
#   'погрузиться',
#   'свой',
#   'мысль',
#   'забыть',
#   'существование',
#   'остальной',
#   '–',
#   'судить',
#   'весь',
#   'прорабатывать',
#   'очередной',
#   'теория',
#   'от',
#   'мысль',
#   'отвлечь',
#   'райтновый',
#   '–',
#   'только',
#   'корпус',
#   'пустовать',
#   'доктор',
#   'вздрогнуть',
#   'резко',
#   'выходить',
#   'транс',
#   '–',
#   'что',
#   '–',
#   'один',
#   'человек',
#   'находиться',
#   'свой',
#   'комната',
#   'время',
#   'нападение',
#   '–',
#   'но',
#   'это',
#   'мочь',
#   'насколько',
#   'помнить',
#   'лаборатория',
#   'райтновый',
#   'сделать',
#   'небольшой',
#   'пауза',
#   'наблюдать',
#   'реакция',
#   'доктор',
#   '–',
#   'это',
#   'джо',
#   'и',
#   'выжить',
#   'доктор',
#   'округлить',
#   'глаз',
#   'встать',
#   'удивление',
#   '–',
#   'джо',
#   'господь',
#   'джо',
#   'выжить',
#   'он',
#   'выйти',
#   'стол',
#   'расхохотаться',
#   'затем',
#   'продолжить',
#   '–',
#   'здоровяк',
#   'джо',
#   'выжить',
#   'вот',
#   'это',
#   'он',
#   'недолюбливать',
#   'провоцировать',
#   'самый',
#   'мой',
#   'враждебный',
#   'отношение',
#   'отношение',
#   'знать',
#   'рад',
#   'слышать',
#   'новость',
#   'доктор',
#   'обойти',
#   'свой',
#   'стул',
#   'облокотиться',
#   'затем',
#   'снова',
#   'рассмеяться',
#   '–',
#   'это',
#   'он',
#   'стоять',
#   'два',
#   'метр',
#   'разъярённый',
#   'титан',
#   'растеряться',
#   'сам',
#   'судьба',
#   'удивиться',
#   'мужество',
#   'щедро',
#   'наградить',
#   'доктор',
#   'покачать',
#   'голова',
#   'находиться',
#   'впечатление',
#   'но',
#   'внезапно',
#   'улыбка',
#   'сойти',
#   'губа',
#   'тревога',
#   'посмотреть',
#   'райтновый',
#   '–',
#   'алекс…',
#   'тот',
#   'вопросительно',
#   'поднять',
#   'правый',
#   'бровь',
#   'ангус',
#   'отрывать',
#   'взгляд',
#   'быстро',
#   'сесть',
#   'упереться',
#   'локоть',
#   'стол',
#   'вытягивать',
#   'шея',
#   '–',
#   'но',
#   'почему',
#   'вы',
#   'встретиться',
#   'быть',
#   'выжить',
#   'они…',
#   'пережить',
#   'следующий',
#   'ночь',
#   'в',
#   'глаз',
#   'райтновый',
#   'мгновение',
#   'проскользнуть',
#   'еле',
#   'заметный',
#   'удивление',
#   '–',
#   'это',
#   'знать',
#   'кроме',
#   'спастись',
#   'четверо',
#   '–',
#   'укрыться',
#   'я',
#   'бункер',
#   'а',
#   'наутро',
#   'найти',
#   'доставить',
#   'некоторый',
#   'количество',
#   'проблема',
#   'теперь',
#   'ангус',
#   'вопросительно',
#   'поднять',
#   'бровь',
#   '–',
#   'дело',
#   '–',
#   'продолжать',
#   'райтновый',
#   '–',
#   'собираться',
#   'искать',
#   'выжить',
#   'джо',
#   'хотеть',
#   'взять',
#   'ангара',
#   'оба',
#   'ровер',
#   'немедленно',
#   'отправиться',
#   'порт',
#   'деметрион',
#   'связаться',
#   'земля',
#   'требовать',
#   'немедленный',
#   'эвакуация',
#   'пропускать',
#   'деталь',
#   '–',
#   'крепко',
#   'повздорить',
#   'прийтись',
#   'немного',
#   'успокоить',
#   'один',
#   'эффективный',
#   'метод',
#   'райтновый',
#   'хрустнуть',
#   'костяшка',
#   'палец',
#   'правый',
#   'рука',
#   'демонстрировать',
#   'остальной',
#   'быть',
#   'метод',
#   '–',
#   'закончиться',
#   'выжить',
#   'примкнуть',
#   'джо',
#   'уехать',
#   'один',
#   'ровер',
#   'оставить',
#   'второй',
#   '–',
#   'продолжить',
#   'райтновый',
#   'этот',
#   'слово',
#   'кулак',
#   'крепко',
#   'сжаться',
#   'эмилия',
#   'мягкий',
#   'спокойный',
#   'голос',
#   'обратиться',
#   'он',
#   '–',
#   'ты',
#   'должный',
#   'винить',
#   'алекс',
#   'они',
#   'напугаться',
#   'просто',
#   'спасать',
#   'свой',
#   'жизнь',
#   'в',
#   'конец',
#   'конец',
#   'оставить',
#   'ты',
#   'второй',
#   'ровер',
#   'она',
#   'дружелюбно',
#   'улыбнуться',
#   'райтновый',
#   'лишь',
#   'поднять',
#   'полный',
#   'гнев',
#   'взгляд',
#   'голос',
#   'спокойный',
#   'впервые',
#   'начать',
#   'выходить',
#   '–',
#   'о',
#   'ровер',
#   'оставить',
#   'только',
#   'никто',
#   'предупредить',
#   'стоять',
#   'двигатель',
#   'тот',
#   'причина',
#   'находиться',
#   'плановый',
#   'ремонт',
#   'вот',
#   'ирония',
#   'встретиться',
#   'джо',
#   'несмотря',
#   'обстоятельство',
#   'погибнуть',
#   'именно',
#   'мой',
#   'рука',
#   '–',
#   'доктор',
#   'ангус',
#   'поймать',
#   'гневный',
#   'взгляд',
#   'райтновый',
#   'почувствовать',
#   'неуютный',
#   'барни',
#   'отвлечься',
#   'свой',
#   'мысль',
#   'всякий',
#   'случай',
#   'насторожиться',
#   'алекс',
#   'быстро',
#   'взять',
#   'рука',
#   'разжать',
#   'кулак',
#   'возобновлять',
#   'нормальный',
#   'кровообращение',
#   'он',
#   'положить',
#   'рука',
#   'ладонь',
#   'стол',
#   'глубоко',
#   'вздохнуть',
#   'продолжить',
#   '–',
#   'просить',
#   'прощение',
#   'сцена',
#   'джо',
#   'знать',
#   'ровер',
#   'ход',
#   'собираться',
#   'быстро',
#   'починить',
#   'помощь',
#   'свой',
#   'сторонник',
#   'но',
#   'решить',
#   'остаться',
#   'попросту',
#   'плюнуть',
#   'ремонт',
#   'взять',
#   'ровер',
#   'трусливо',
#   'сбежать',
#   'я',
#   'заниматься',
#   'установка',
#   'двигатель',
#   'ангус',
#   'найти',
#   'ангар',
#   '–',
#   'вместе',
#   'успеть',
#   'закончить',
#   'темнота',
#   'подготовиться',
#   'дорога',
#   '–',
#   'вы',
#   'добраться',
#   'сюда',
#   'происшествие',
#   '–',
#   'спросить',
#   'гордон',
#   'время',
#   'внимательно',
#   'слушать',
#   'райтновый',
#   'хотеть',
#   'ответить',
#   'опередить',
#   'доктор',
#   '–',
#   'на',
#   'удивление',
#   '–',
#   'сказать',
#   '–',
#   'когда',
#   'стемнеть',
#   'успеть',
#   'отъехать',
#   'альф',
#   'полтора',
#   'десяток',
#   'километр',
#   'один',
#   'титан',
#   'свой',
#   'путь',
#   'встретить',
#   'лично',
#   'показаться',
#   'весьма',
#   'странный',
#   'с',
#   'сторона',
#   '–',
#   'грех',
#   'жаловаться',
#   'вполне',
#   'устроить',
#   'вариант',
#   'с',
#   'этот',
#   'слово',
#   'встать',
#   'бросить',
#   'взгляд',
#   'пустой',
#   'тарелка',
#   'остальной',
#   'робко',
#   'спросить',
#   '–',
#   'всё',
#   'закончить',
#   'завтракать',
#   'гордон',
#   'понять',
#   'намёк',
#   'встать',
#   'стол',
#   '–',
#   'да',
#   '–',
#   'ответить',
#   '–',
#   'обещать',
#   'показать',
#   'запись',
#   'ровер',
#   'сделать',
#   'путь',
#   ...],
#  ['давно',
#   'публиковать',
#   'новость',
#   'наш',
#   'проект',
#   'тем',
#   'время',
#   'работа',
#   'кипеть',
#   'мы',
#   'рассказать',
#   'сегодня',
#   'речь',
#   'пойти',
#   'обновление',
#   'сервис',
#   'частный',
#   'объявление',
#   'стиль',
#   'немного',
#   'напомнить',
#   'суть',
#   'тот',
#   'забыть',
#   'вообще',
#   'знать',
#   'момент',
#   'существование',
#   '–',
#   'это',
#   'сервис',
#   'частный',
#   'объявление',
#   'создать',
#   'группа',
#   'разработчик',
#   'другой',
#   'позволять',
#   'мгновенно',
#   'разместить',
#   'свой',
#   'сообщение',
#   'купля',
#   'продажа',
#   'угодный',
#   'также',
#   'аренда',
#   'квартира',
#   'вакансия',
#   'так',
#   'далее',
#   'подробный',
#   'ознакомиться',
#   'сервис',
#   'посетить',
#   'сайт',
#   'посмотреть',
#   'видео',
#   'ресурс',
#   'существовать',
#   'полгода',
#   'за',
#   'это',
#   'время',
#   'сильно',
#   'измениться',
#   'постоянно',
#   'вестись',
#   'работа',
#   'улучшение',
#   'функционал',
#   'мы',
#   'собрать',
#   'отзыв',
#   'пользователь',
#   'прошлый',
#   'публикация',
#   'постараться',
#   'улучшить',
#   'система',
#   'сегодня',
#   'представлять',
#   'обновить',
#   'версия',
#   'мобильный',
#   'приложение',
#   'который',
#   'бесплатно',
#   'скачать',
#   'среди',
#   'обновление',
#   'хотеться',
#   'отметить',
#   'следующий',
#   '•',
#   'добавить',
#   'возможность',
#   'авторизация',
#   'большинство',
#   'популярный',
#   'соц',
#   'сеть',
#   'одноклассник',
#   '•',
#   'возможность',
#   'быстрый',
#   'шаринг',
#   'отдельный',
#   'объявление',
#   'социальный',
#   'сеть',
#   '•',
#   'у',
#   'пользователь',
#   'появиться',
#   'возможность',
#   'делиться',
#   'ссылка',
#   'результат',
#   'поиск',
#   'целый',
#   'категория',
#   '•',
#   'в',
#   'поиск',
#   'категория',
#   'оставить',
#   'наиболее',
#   'востребовать',
#   'раздел',
#   'удалить',
#   'категория',
#   'знакомство',
#   'купон',
#   '•',
#   'сделать',
#   'полноценный',
#   'админк',
#   'возможность',
#   'бан',
#   'постмодерация',
#   'учёт',
#   'статистика',
#   'объявление',
#   'город',
#   'категория',
#   'загрузка',
#   '•',
#   'убрать',
#   'хэштэг',
#   'текст',
#   'объявление',
#   'они',
#   'остаться',
#   'создание',
#   'построить',
#   'поисковый',
#   'система',
#   'в',
#   'дальнейший',
#   'быть',
#   'рассмотреть',
#   'вариант',
#   'полный',
#   'отказ',
#   'хэштэг',
#   'практика',
#   'показать',
#   'далеко',
#   'весь',
#   'пользователь',
#   'сервис',
#   'частный',
#   'объявление',
#   'понятный',
#   'удобный',
#   'логика',
#   'создание',
#   'объявление',
#   'стиль',
#   'твиттер',
#   '•',
#   'решить',
#   'проблема',
#   'индексация',
#   'поисковый',
#   'система',
#   'в',
#   'общий',
#   'веб',
#   'версия',
#   'мобильный',
#   'приложение',
#   'пертерпеть',
#   'полезный',
#   'изменение',
#   'мы',
#   'очень',
#   'надеяться',
#   'наш',
#   'ресурс',
#   'полезный',
#   'удобно',
#   'просто',
#   'пользоваться',
#   'по',
#   'мера',
#   'возможность',
#   'быть',
#   'делиться',
#   'вы',
#   'новость',
#   'рассказывать',
#   'делать',
#   'делать',
#   'насколько',
#   'это',
#   'эффективно',
#   'быть',
#   'рада',
#   'услышать',
#   'ваш',
#   'замечание',
#   'вопрос',
#   'пожелание',
#   'Новинки',
#   'сервиса',
#   'Selloby.ru',
#   'Блог',
#   'компании',
#   'Фестиваль',
#   '404',
#   'объявления',
#   'Новинки',
#   'сервиса',
#   'Selloby.ru',
#   'Блог',
#   'компании',
#   'Фестиваль',
#   '404',
#   'объявления']]

# %%
print(df.shape[0] // 3)
print(df.shape[0] // 3 * 2)
print(df.shape[0])
# Out:
# 71160
# 142320
# 213480

# %%
df.loc[:71160, :].to_csv("part1.csv", index=True)
df.loc[71161:142320, :].to_csv("part2.csv", index=True)
df.loc[142321:, :].to_csv("part3.csv", index=True)

# %%
part1 = pd.read_csv("part1.csv")
part1
# Out:
#                                                    title  \
# 0      LinkedIn автоматизировал добавление в профиль ...
# 1      MobileFaker: фальшивые звонки как социальное о...
# 2      Jelastic is the new kind of Java hosting platf...
# 3      В Mozilla работают над версией Firefox OS для ...
# 4                          Как я спам слал Oracle Oracle
# ...                                                  ...
# 71156  Как быть идеальным клиентом Блог компании Used...
# 71157  Венсан Жанти: зачем крупным компаниям дружить ...
# 71158  Как сделать так, чтобы видео продавало: кейсы ...
# 71159  Тинькофф-банк ожидает получить больше прибыли ...
# 71160  Меньше, да лучше: Mozilla Firefox «худеет», чт...
#
#                                                     text  rating
# 0      разработчик объявить появиться возможность доб...      28
# 1      с свой мобильник заказывать фальшивый звонок у...      20
# 2      облачный хостинг ранее разработать новый прило...      63
# 3      относительно новый операционный система которы...      20
# 4      введение в небольшой статья хотеть рассказать ...      71
# ...                                                  ...     ...
# 71156  быть клиент обычный часть наш жизнь мало клиен...      32
# 71157  этот осень команда «леруа мерлен» совместно пр...      18
# 71158  в статья пойти речь роль видео современный инт...      54
# 71159  банковский предприятие олег тинькова опубликов...      20
# 71160  фонд продолжать выстраивать свой бизнес вокруг...      22
#
# [71161 rows x 3 columns]

# %%
part2 = pd.read_csv("part2.csv", index_col="Unnamed: 0")
part2
# Out:
#                                                     title  \
# 71161   8 советов по анализу трафика Блог компании dev...
# 71162   В ДНК сохранили операционную систему и видеоро...
# 71163   Крепление системного блока к столешнице DIY ил...
# 71164   Немного воскресной инфографики #2 Инфографика ...
# 71165   Остросюжетная история об отсутствии синхрониза...
# ...                                                   ...
# 142316  Как устроена IT-приёмная в Mail.Ru Group Блог ...
# 142317  Техника Помидора по-русски Управление проектам...
# 142318  Копирасты наносят новый удар: Вконтакте начал ...
# 142319  Утечка: iOS 7 на iPad Блог компании Rozetked i...
# 142320  Колосс на глиняных ногах. Принципы управления ...
#
#                                                      text  rating
# 71161   часто особенно небольшой компания бывать получ...      49
# 71162   в скорый время человечество генерировать данны...     118
# 71163   совсем коротенький пост оптимизация рабочий ме...     190
# 71164   разработчик проделать хороший работа отцифрова...      31
# 71165   «против глупость сам бог бороться бессильны» ф...     263
# ...                                                   ...     ...
# 142316  в любой компания сотрудник ежедневно обращатьс...     126
# 142317  изучать хабра различный подход натолкнуться те...     179
# 142318  по многичисленный сообщение число сми социальн...     219
# 142319  так получиться именно наш команда – первый мир...      19
# 142320  часто бывать казаться сплотить коллектив профе...     291
#
# [71160 rows x 3 columns]

# %%
part3 = pd.read_csv("part3.csv", index_col="Unnamed: 0")
part3
# Out:
#                                                     title  \
# 142321  Брет Виктор — Изобретая по Принципу (Bret Vict...
# 142322         Bison для JavaScript JavaScript javascript
# 142323  Webmoney в Украине: вести с полей и петиция к ...
# 142324  Как продвигать мероприятия в соцсетях? История...
# 142325     Сортировка треков в плейлисте VK Python python
# ...                                                   ...
# 213475  Как научить Wordpress движок дружить с Proxy? ...
# 213476  Опубликованы обучающие материалы по Visual Stu...
# 213477  PostSharp. Отложенная загрузка зависимостей .N...
# 213478  Обзор клавиатур для контроллера PS3 Игры и игр...
# 213479  Сегодня 28.07 Онлайн разбираем на винтики: iOs...
#
#                                                      text  rating
# 142321  чудесный необычный вдохновлять заставлять заду...     290
# 142322  нет а полноценный генератор яваскриптовый парс...     145
# 142323  спешить первый строка сказать хороший ситуация...      49
# 142324  мы знать поддержка один массовый городской пра...      50
# 142325  начать писать скрипт весёлый новость ещё подос...     178
# ...                                                   ...     ...
# 213475  я заниматься разработка локальный корпоративны...      11
# 213476  привет хабра буквально вчера опубликовать анон...      52
# 213477  кусок код представить ниже наверняка писать а ...      38
# 213478  в принцип накладный клавиатура игровой контрол...       3
# 213479  онлайн трансляция закончиться весь спасибо зап...      22
#
# [71159 rows x 3 columns]
